# %% [markdown]
# # Project 2: Billboard Hits

# %% [markdown]
# ## 1. Problem statement

# %% [markdown]
# - Does the genre of a song affect how long it takes to peak in the top 100?
# - Does the length of a song affect how long it takes to peak in the top 100?
# - Does the amount of time a song takes to peak affect how long it stays in the top 100?

# %% [markdown]
# ## 2. Importing relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 3. Loading the data

# %%
df = pd.read_csv('assets/billboard.csv', na_values='*')

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week     ...      x67th.week  x68th.week  x69th.week  \
# 0       63.0       49.0     ...             NaN         NaN         NaN
# 1        8.0        6.0     ...             NaN         NaN         NaN
# 2       48.0       43.0     ...             NaN         NaN         NaN
# 3       23.0       18.0     ...             NaN         NaN         NaN
# 4       47.0       45.0     ...             NaN         NaN         NaN
#
#    x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  x75th.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x76th.week
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 83 columns]

# %% [markdown]
# ## 4. Assumptions

# %% [markdown]
# - The genre of the song/ artist is correctly categorized
# - The columns beginning with 'x' indicate a timeline, where x1st.week is the first week that the track enters the Top 100
# - The columns beginning with 'x' contain the rank of the track if it was currently on the Top 100 Billboards and a null value if it was no longer within the Top 100 Billboards.

# %% [markdown]
# ## 5. Cleaning the data

# %% [markdown]
# ### a. Is the column 'year' useful?

# %%
df['year'].value_counts()
# Out:
# 2000    317
# Name: year, dtype: int64

# %% [markdown]
# **There's only one value in the column so it wouldn't help much.**

# %% [markdown]
# ### b. Cleaning artist name column

# %%
names = df['artist.inverted'].unique()

# %%
print sorted(names)
# Out:
# ['2 Pac', '2Ge+her', '3 Doors Down', '504 Boyz', '98\xa1', 'A*Teens', 'Aaliyah', 'Adams, Yolanda', 'Adkins, Trace', 'Aguilera, Christina', 'Alice Deejay', 'Allan, Gary', 'Amber', 'Anastacia', 'Anthony, Marc', 'Avant', 'BBMak', 'Backstreet Boys, The', 'Badu, Erkyah', 'Baha Men', 'Barenaked Ladies', 'Beenie Man', 'Before Dark', 'Bega, Lou', 'Big Punisher', 'Black Rob', 'Black, Clint', 'Blaque', 'Blige, Mary J.', 'Blink-182', 'Bloodhound Gang', 'Bon Jovi', 'Braxton, Toni', 'Brock, Chad', 'Brooks & Dunn', 'Brooks, Garth', 'Byrd, Tracy', 'Cagle, Chris', "Cam'ron", 'Carey, Mariah', 'Carter, Aaron', 'Carter, Torrey', 'Changing Faces', 'Chesney, Kenny', 'Clark Family Experience', 'Clark, Terri', 'Common', 'Counting Crows', 'Creed', 'Cyrus, Billy Ray', "D'Angelo", 'DMX', 'Da Brat', 'Davidson, Clay', 'De La Soul', "Destiny's Child", 'Diffie, Joe', 'Dion, Celine', 'Dixie Chicks, The', 'Dr. Dre', 'Drama', 'Dream', 'Eastsidaz, The', 'Eiffel 65', 'Elliott, Missy "Misdemeanor"', 'Eminem', 'En Vogue', 'Estefan, Gloria', 'Evans, Sara', 'Eve', 'Everclear', 'Fabian, Lara', 'Fatboy Slim', 'Filter', 'Foo Fighters', 'Fragma', 'Funkmaster Flex', 'Ghostface Killah', 'Gill, Vince', 'Gilman, Billy', 'Ginuwine', 'Goo Goo Dolls', 'Gray, Macy', 'Griggs, Andy', 'Guy', 'Hanson', 'Hart, Beth', 'Heatherly, Eric', 'Henley, Don', 'Herndon, Ty', 'Hill, Faith', 'Hoku', 'Hollister, Dave', 'Hot Boys', 'Houston, Whitney', 'IMx', 'Ice Cube', 'Ideal', 'Iglesias, Enrique', 'J-Shin', 'Ja Rule', 'Jackson, Alan', 'Jagged Edge', 'Janet', 'Jay-Z', 'Jean, Wyclef', 'Joe', 'John, Elton', 'Jones, Donell', 'Jordan, Montell', 'Juvenile', 'Kandi', 'Keith, Toby', 'Kelis', 'Kenny G', 'Kid Rock', 'Kravitz, Lenny', 'Kumbia Kings', 'LFO', 'LL Cool J', 'Larrieux, Amel', 'Lawrence, Tracy', 'Levert, Gerald', 'Lil Bow Wow', 'Lil Wayne', "Lil' Kim", "Lil' Mo", "Lil' Zane", 'Limp Bizkit', 'Lonestar', 'Lopez, Jennifer', 'Loveless, Patty', 'Lox', 'Lucy Pearl', 'Ludacris', 'M2M', 'Madison Avenue', 'Madonna', 'Martin, Ricky', 'Mary Mary', 'Master P', 'McBride, Martina', 'McEntire, Reba', 'McGraw, Tim', 'McKnight, Brian', 'Messina, Jo Dee', 'Metallica', 'Montgomery Gentry', 'Montgomery, John Michael', 'Moore, Chante', 'Moore, Mandy', 'Mumba, Samantha', 'Musiq', 'Mya', 'Mystikal', "N'Sync", 'Nas', 'Nelly', 'Next', 'Nine Days', 'No Doubt', 'Nu Flavor', 'Offspring, The', 'Paisley, Brad', 'Papa Roach', 'Pearl Jam', 'Pink', 'Price, Kelly', 'Profyle', 'Puff Daddy', 'Q-Tip', 'R.E.M.', 'Rascal Flatts', 'Raye, Collin', 'Red Hot Chili Peppers', 'Rimes, LeAnn', 'Rogers, Kenny', 'Ruff Endz', 'Sammie', 'Santana', 'Savage Garden', 'SheDaisy', 'Sheist, Shade', 'Shyne', 'Simpson, Jessica', 'Sisqo', 'Sister Hazel', 'Smash Mouth', 'Smith, Will', 'Son By Four', 'Sonique', 'SoulDecision', 'Spears, Britney', 'Spencer, Tracie', 'Splender', 'Sting', 'Stone Temple Pilots', 'Stone, Angie', 'Strait, George', 'Sugar Ray', 'TLC', 'Tamar', 'Tamia', 'Third Eye Blind', 'Thomas, Carl', 'Tippin, Aaron', 'Train', 'Trick Daddy', 'Trina', 'Tritt, Travis', 'Tuesday', 'Urban, Keith', 'Usher', 'Vassar, Phil', 'Vertical Horizon', 'Vitamin C', 'Walker, Clay', 'Wallflowers, The', 'Westlife', 'Williams, Robbie', 'Wills, Mark', 'Worley, Darryl', 'Wright, Chely', 'Yankee Grey', 'Yearwood, Trisha', 'Ying Yang Twins', 'Zombie Nation', 'matchbox twenty']

# %% [markdown]
# **Seems like the names are in order (I tried to look through everything) and no further cleaning is required at the moment.**

# %% [markdown]
# ### c. What about the column 'time'?

# %% [markdown]
# It looks like it refers to the length of the track. Let's format it to return length of the track in seconds.

# %% [markdown]
# Each value seems to be formatted: m,s,ms. For the purposes of this project, we will drop the millisecond(ms).

# %%
def get_sec(x):
    x_list = x.split(',')
    return int(x_list[0]) * 60 + int(x_list[1])

# %%
df['track_length_seconds'] = df['time'].map(get_sec)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week          ...           x68th.week  x69th.week  \
# 0       63.0       49.0          ...                  NaN         NaN
# 1        8.0        6.0          ...                  NaN         NaN
# 2       48.0       43.0          ...                  NaN         NaN
# 3       23.0       18.0          ...                  NaN         NaN
# 4       47.0       45.0          ...                  NaN         NaN
#
#    x70th.week  x71st.week  x72nd.week  x73rd.week  x74th.week  x75th.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x76th.week  track_length_seconds
# 0         NaN                   218
# 1         NaN                   258
# 2         NaN                   247
# 3         NaN                   225
# 4         NaN                   218
#
# [5 rows x 84 columns]

# %% [markdown]
# ### d. Cleaning the 'genre' column

# %%
genres = df['genre'].unique()

# %%
print sorted(genres)
# Out:
# ['Country', 'Electronica', 'Gospel', 'Jazz', 'Latin', 'Pop', 'R & B', 'R&B', 'Rap', 'Reggae', 'Rock', "Rock'n'roll"]

# %%
def clean_genre(x):
    if x == 'R & B':
        return 'R&B'
    elif x == "Rock'n'roll":
        return 'Rock'
    else:
        return x

# %%
df['genre_clean'] = df['genre'].map(clean_genre)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week     ...       x69th.week  x70th.week  x71st.week  \
# 0       63.0       49.0     ...              NaN         NaN         NaN
# 1        8.0        6.0     ...              NaN         NaN         NaN
# 2       48.0       43.0     ...              NaN         NaN         NaN
# 3       23.0       18.0     ...              NaN         NaN         NaN
# 4       47.0       45.0     ...              NaN         NaN         NaN
#
#    x72nd.week  x73rd.week  x74th.week  x75th.week  x76th.week  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
#    track_length_seconds  genre_clean
# 0                   218         Rock
# 1                   258         Rock
# 2                   247         Rock
# 3                   225         Rock
# 4                   218         Rock
#
# [5 rows x 85 columns]

# %% [markdown]
# ### e. Formatting the columns 'date.entered' and 'date.peaked'

# %%
df['date_entered'] = df['date.entered'].map(pd.to_datetime)
df['date_peaked'] = df['date.peaked'].map(pd.to_datetime)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week     ...       x71st.week  x72nd.week  x73rd.week  \
# 0       63.0       49.0     ...              NaN         NaN         NaN
# 1        8.0        6.0     ...              NaN         NaN         NaN
# 2       48.0       43.0     ...              NaN         NaN         NaN
# 3       23.0       18.0     ...              NaN         NaN         NaN
# 4       47.0       45.0     ...              NaN         NaN         NaN
#
#    x74th.week  x75th.week  x76th.week  track_length_seconds  genre_clean  \
# 0         NaN         NaN         NaN                   218         Rock
# 1         NaN         NaN         NaN                   258         Rock
# 2         NaN         NaN         NaN                   247         Rock
# 3         NaN         NaN         NaN                   225         Rock
# 4         NaN         NaN         NaN                   218         Rock
#
#    date_entered  date_peaked
# 0    2000-09-23   2000-11-18
# 1    2000-02-12   2000-04-08
# 2    1999-10-23   2000-01-29
# 3    2000-08-12   2000-09-16
# 4    2000-08-05   2000-10-14
#
# [5 rows x 87 columns]

# %% [markdown]
# Let's add a column that shows the number of weeks a track took to peak on the billboard.

# %%
df['weeks_to_peak'] = df['date_peaked'] - df['date_entered']

# %%
def get_weeks(x):
    y = str(x).split()
    return float(y[0])/7.

# %%
df['weeks_to_peak'] = df['weeks_to_peak'].map(get_weeks)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week      ...        x72nd.week  x73rd.week  x74th.week  \
# 0       63.0       49.0      ...               NaN         NaN         NaN
# 1        8.0        6.0      ...               NaN         NaN         NaN
# 2       48.0       43.0      ...               NaN         NaN         NaN
# 3       23.0       18.0      ...               NaN         NaN         NaN
# 4       47.0       45.0      ...               NaN         NaN         NaN
#
#    x75th.week  x76th.week  track_length_seconds  genre_clean  date_entered  \
# 0         NaN         NaN                   218         Rock    2000-09-23
# 1         NaN         NaN                   258         Rock    2000-02-12
# 2         NaN         NaN                   247         Rock    1999-10-23
# 3         NaN         NaN                   225         Rock    2000-08-12
# 4         NaN         NaN                   218         Rock    2000-08-05
#
#    date_peaked  weeks_to_peak
# 0   2000-11-18            8.0
# 1   2000-04-08            8.0
# 2   2000-01-29           14.0
# 3   2000-09-16            5.0
# 4   2000-10-14           10.0
#
# [5 rows x 88 columns]

# %% [markdown]
# ### f. Formatting the timeline

# %%
df.dropna(how='all', axis=1, inplace=True)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week      ...        x61st.week  x62nd.week  x63rd.week  \
# 0       63.0       49.0      ...               NaN         NaN         NaN
# 1        8.0        6.0      ...               NaN         NaN         NaN
# 2       48.0       43.0      ...               NaN         NaN         NaN
# 3       23.0       18.0      ...               NaN         NaN         NaN
# 4       47.0       45.0      ...               NaN         NaN         NaN
#
#    x64th.week  x65th.week  track_length_seconds  genre_clean  date_entered  \
# 0         NaN         NaN                   218         Rock    2000-09-23
# 1         NaN         NaN                   258         Rock    2000-02-12
# 2         NaN         NaN                   247         Rock    1999-10-23
# 3         NaN         NaN                   225         Rock    2000-08-12
# 4         NaN         NaN                   218         Rock    2000-08-05
#
#    date_peaked  weeks_to_peak
# 0   2000-11-18            8.0
# 1   2000-04-08            8.0
# 2   2000-01-29           14.0
# 3   2000-09-16            5.0
# 4   2000-10-14           10.0
#
# [5 rows x 77 columns]

# %% [markdown]
# **Some of the weeks were totally empty! So we got rid of them.**

# %% [markdown]
# ### h. How long does a track stay on the billboard?

# %%
df['weeks_on_billboard'] = df.iloc[:,7:72].count(axis=1)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week         ...          x62nd.week  x63rd.week  \
# 0       63.0       49.0         ...                 NaN         NaN
# 1        8.0        6.0         ...                 NaN         NaN
# 2       48.0       43.0         ...                 NaN         NaN
# 3       23.0       18.0         ...                 NaN         NaN
# 4       47.0       45.0         ...                 NaN         NaN
#
#    x64th.week  x65th.week  track_length_seconds  genre_clean  date_entered  \
# 0         NaN         NaN                   218         Rock    2000-09-23
# 1         NaN         NaN                   258         Rock    2000-02-12
# 2         NaN         NaN                   247         Rock    1999-10-23
# 3         NaN         NaN                   225         Rock    2000-08-12
# 4         NaN         NaN                   218         Rock    2000-08-05
#
#    date_peaked  weeks_to_peak  weeks_on_billboard
# 0   2000-11-18            8.0                  28
# 1   2000-04-08            8.0                  26
# 2   2000-01-29           14.0                  33
# 3   2000-09-16            5.0                  24
# 4   2000-10-14           10.0                  21
#
# [5 rows x 78 columns]

# %% [markdown]
# ### i. What is the highest rank obtained by a track?

# %%
df['highest_rank'] = df.iloc[:,7:72].min(axis=1)

# %%
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#    x2nd.week  x3rd.week      ...       x63rd.week  x64th.week  x65th.week  \
# 0       63.0       49.0      ...              NaN         NaN         NaN
# 1        8.0        6.0      ...              NaN         NaN         NaN
# 2       48.0       43.0      ...              NaN         NaN         NaN
# 3       23.0       18.0      ...              NaN         NaN         NaN
# 4       47.0       45.0      ...              NaN         NaN         NaN
#
#    track_length_seconds  genre_clean  date_entered  date_peaked  \
# 0                   218         Rock    2000-09-23   2000-11-18
# 1                   258         Rock    2000-02-12   2000-04-08
# 2                   247         Rock    1999-10-23   2000-01-29
# 3                   225         Rock    2000-08-12   2000-09-16
# 4                   218         Rock    2000-08-05   2000-10-14
#
#    weeks_to_peak  weeks_on_billboard  highest_rank
# 0            8.0                  28           1.0
# 1            8.0                  26           1.0
# 2           14.0                  33           1.0
# 3            5.0                  24           1.0
# 4           10.0                  21           1.0
#
# [5 rows x 79 columns]

# %% [markdown]
# ## 6. What does the data tell us?

# %% [markdown]
# ### a. What's almost immediately apparent?

# %%
df.iloc[:,72:].describe(include='all')
# Out:
#         track_length_seconds genre_clean         date_entered  \
# count             317.000000         317                  317
# unique                   NaN          10                   68
# top                      NaN        Rock  2000-01-29 00:00:00
# freq                     NaN         137                   11
# first                    NaN         NaN  1999-06-05 00:00:00
# last                     NaN         NaN  2000-12-30 00:00:00
# mean              242.425868         NaN                  NaN
# std                42.401618         NaN                  NaN
# min               156.000000         NaN                  NaN
# 25%               219.000000         NaN                  NaN
# 50%               236.000000         NaN                  NaN
# 75%               257.000000         NaN                  NaN
# max               470.000000         NaN                  NaN
#
#                 date_peaked  weeks_to_peak  weeks_on_billboard  highest_rank
# count                   317     317.000000          317.000000    317.000000
# unique                   53            NaN                 NaN           NaN
# top     2000-12-02 00:00:00            NaN                 NaN           NaN
# freq                     17            NaN                 NaN           NaN
# first   2000-01-01 00:00:00            NaN                 NaN           NaN
# last    2000-12-30 00:00:00            NaN                 NaN           NaN
# mean                    NaN       7.463722           16.741325     44.123028
# std                     NaN       5.838229            9.083785     29.223722
# min                     NaN       0.000000            1.000000      1.000000
# 25%                     NaN       3.000000           10.000000     20.000000
# 50%                     NaN       7.000000           18.000000     42.000000
# 75%                     NaN      10.000000           20.000000     70.000000
# max                     NaN      45.000000           57.000000     99.000000

# %% [markdown]
# Although there are other columns with numerical data, only the above columns actually refer to a component of the data that could be continuous.

# %%
df['highest_rank'][df['highest_rank'] == 1.0].count()
# Out:
# 17

# %% [markdown]
# - 'weeks_to_peak' has a minimum value of 0
#     - There are tracks which hit Number 1 the moment they got into top 100
# - 'weeks_to_peak' has a mean value of 7.5
#     - On average, it takes a track 7.5 weeks to hit its highest rank
# - only 17 tracks reached the number 1 spot

# %% [markdown]
# ### b. What else can we find out?

# %% [markdown]
# #### For the tracks that got to number 1, how long did they take?

# %%
df[['weeks_to_peak']][df['highest_rank'] == 1.0].describe()
# Out:
#        weeks_to_peak
# count      17.000000
# mean       13.529412
# std         8.668316
# min         5.000000
# 25%         8.000000
# 50%        12.000000
# 75%        13.000000
# max        39.000000

# %% [markdown]
# #### What is the highest rank obtained by each genre and how many tracks of each genre hit the top 100?

# %%
pd.pivot_table(df, index=['genre_clean'], values=['highest_rank'],aggfunc=[min, len], margins=True)
# Out:
#                      min          len
#             highest_rank highest_rank
# genre_clean
# Country              1.0         74.0
# Electronica          6.0          4.0
# Gospel              57.0          1.0
# Jazz                 7.0          1.0
# Latin                1.0          9.0
# Pop                  5.0          9.0
# R&B                 14.0         23.0
# Rap                  2.0         58.0
# Reggae              54.0          1.0
# Rock                 1.0        137.0
# All                  1.0        317.0

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(df.iloc[:,72:].corr(), linewidths=.5, ax= ax);

# %%
pd.melt(df, id_vars=['track','genre'],value_vars=['weeks_to_peak', 'highest_rank'])
# Out:
#                                                  track        genre  \
# 0                             Independent Women Part I         Rock
# 1                                         Maria, Maria         Rock
# 2                                   I Knew I Loved You         Rock
# 3                                                Music         Rock
# 4                Come On Over Baby (All I Want Is You)         Rock
# 5                                Doesn't Really Matter         Rock
# 6                                          Say My Name  Rock'n'roll
# 7                                          Be With You        Latin
# 8                                           Incomplete  Rock'n'roll
# 9                                               Amazed      Country
# 10                                    It's Gonna Be Me  Rock'n'roll
# 11                                   What A Girl Wants  Rock'n'roll
# 12                                 Everything You Want  Rock'n'roll
# 13                                 With Arms Wide Open  Rock'n'roll
# 14                                           Try Again  Rock'n'roll
# 15                                                Bent         Rock
# 16                               Thank God I Found You         Rock
# 17                                             Breathe          Rap
# 18                   Case Of The Ex (Whatcha Gonna Do)  Rock'n'roll
# 19                                      He Loves U Not         Rock
# 20                                He Wasn't Man Enough         Rock
# 21                                      You Sang To Me        Latin
# 22                  Give Me Just One Night (Una Noche)         Rock
# 23                                     Jumpin' Jumpin'         Rock
# 24                                          Kryptonite         Rock
# 25                                          Thong Song  Rock'n'roll
# 26                                       I Turn To You  Rock'n'roll
# 27                                My Love Is Your Love  Rock'n'roll
# 28                                        I Wanna Know  Rock'n'roll
# 29                                  Get It On.. Tonite          Rap
# ..                                                 ...          ...
# 604  The Hardest Part Of Breaking Up (Is Getting Ba...        R & B
# 605                                 Don't Call Me Baby  Electronica
# 606                                         Got It All          Rap
# 607                                        Re-Arranged         Rock
# 608                                  Still In My Heart         Rock
# 609                                     3 Little Words        R & B
# 610                         If You Don't Wanna Love Me         Rock
# 611                                         Baby U Are        R & B
# 612                                          L.A. Song      Country
# 613                                  The Quittin' Kind      Country
# 614                                             Do You          Rap
# 615                                 Love Sets You Free         Rock
# 616                                             Riddle         Rock
# 617                                           No Mercy      Country
# 618                                     I'm Outta Love          Pop
# 619                                          Pull Over          Rap
# 620                                              Ta Da          Rap
# 621                                      Dancing Queen          Pop
# 622                                   Where I Wanna Be          Rap
# 623                                          All Good?          Rap
# 624                                             Get Up        R & B
# 625                                     Spanish Guitar         Rock
# 626                                             I Know         Rock
# 627                                       Imagine That          Rap
# 628                                            Souljas          Rap
# 629                                   Cherchez LaGhost        R & B
# 630                                        Freakin' It          Rap
# 631                                      Kernkraft 400         Rock
# 632                                           Got Beef          Rap
# 633                                     Toca's Miracle        R & B
#
#           variable  value
# 0    weeks_to_peak    8.0
# 1    weeks_to_peak    8.0
# 2    weeks_to_peak   14.0
# 3    weeks_to_peak    5.0
# 4    weeks_to_peak   10.0
# 5    weeks_to_peak   10.0
# 6    weeks_to_peak   12.0
# 7    weeks_to_peak   12.0
# 8    weeks_to_peak    7.0
# 9    weeks_to_peak   39.0
# 10   weeks_to_peak   12.0
# 11   weeks_to_peak    7.0
# 12   weeks_to_peak   25.0
# 13   weeks_to_peak   26.0
# 14   weeks_to_peak   13.0
# 15   weeks_to_peak   12.0
# 16   weeks_to_peak   10.0
# 17   weeks_to_peak   24.0
# 18   weeks_to_peak   15.0
# 19   weeks_to_peak   13.0
# 20   weeks_to_peak    7.0
# 21   weeks_to_peak   14.0
# 22   weeks_to_peak    6.0
# 23   weeks_to_peak   14.0
# 24   weeks_to_peak   31.0
# 25   weeks_to_peak   16.0
# 26   weeks_to_peak   11.0
# 27   weeks_to_peak   18.0
# 28   weeks_to_peak   26.0
# 29   weeks_to_peak   16.0
# ..             ...    ...
# 604   highest_rank   87.0
# 605   highest_rank   88.0
# 606   highest_rank   88.0
# 607   highest_rank   88.0
# 608   highest_rank   88.0
# 609   highest_rank   89.0
# 610   highest_rank   89.0
# 611   highest_rank   89.0
# 612   highest_rank   90.0
# 613   highest_rank   90.0
# 614   highest_rank   91.0
# 615   highest_rank   91.0
# 616   highest_rank   92.0
# 617   highest_rank   92.0
# 618   highest_rank   92.0
# 619   highest_rank   93.0
# 620   highest_rank   95.0
# 621   highest_rank   95.0
# 622   highest_rank   95.0
# 623   highest_rank   96.0
# 624   highest_rank   97.0
# 625   highest_rank   98.0
# 626   highest_rank   98.0
# 627   highest_rank   98.0
# 628   highest_rank   98.0
# 629   highest_rank   98.0
# 630   highest_rank   99.0
# 631   highest_rank   99.0
# 632   highest_rank   99.0
# 633   highest_rank   99.0
#
# [634 rows x 4 columns]

# %%
df.to_csv(path_or_buf='billboards2.csv')
