# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Webscraping Project 4 Lab
#
# Week 4 | Day 4

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com (or other sites at your team's discretion). In the second part, the focus is on using listings with salary information to build a model and predict high or low salaries and what features are predictive of that result.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
path_phantom = '//Applications/phantomjs'

# %%
## YOUR CODE HERE
driver = webdriver.PhantomJS(executable_path=path_phantom)

# %%
driver.get(URL)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %% [raw]
# print soup.find('div', class_='result').prettify()

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %%
## YOUR CODE HERE
def extract_location_from_result(result):
    try:
        location = result.find('span', class_='location').text.strip()
    except:
        location = ''
    return location

def extract_title_from_result(result):
    try:
        job_title = result.find('a', class_='jobtitle').text.strip('\n')
    except:
        try:
            job_title = result.find('h2', class_='jobtitle').text.strip('\n')
        except:
            job_title = ''
    return job_title

def extract_summary_from_result(result):
    try:
        summary = result.find('span', class_='summary').text.strip()
    except:
        summary = ''
    return summary

def extract_company_from_result(result):
    try:
        company = result.find('span', class_='company').text.strip()
    except:
        company = ''
    return company

def extract_reviews_from_result(result):
    try:
        sub = result.find('span', class_='slNoUnderline').text.strip()
        if 'review' in sub:
            reviews = sub.split()[0]
    except:
        reviews = ''
    return reviews

def extract_salary_from_result(result):
    try:
        salary = result.find('td', class_='snip').find('nobr').text.strip()
#         salary_text = salary_text.split()
#         salary = float(salary_text[0].strip('$').replace(',',''))
    except:
        salary = ''
    return salary

def get_all_details(result):
    return [extract_title_from_result(result),\
            extract_company_from_result(result),\
            extract_location_from_result(result),\
            extract_reviews_from_result(result),\
            extract_summary_from_result(result),\
            extract_salary_from_result(result)]

# %% [raw]
# data = []
# for i in soup.findAll('div', class_='result'):
#     print i.prettify()
#     print
#     data.append(get_all_details(i))

# %%
import pandas as pd

# %% [raw]
# df = pd.DataFrame(data, columns=['title', 'company', 'location', 'reviews', 'summary', 'salary'])

# %% [raw]
# df

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Atlanta']):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        full_url = url_template.format(city, start)
        driver.get(full_url)
        soup = BeautifulSoup(driver.page_source, 'lxml')
        # Append to the full set of results
        for item in soup.findAll('div', class_='result'):
            results.append(get_all_details(item))
#         pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %%
df = pd.DataFrame(results, columns=['title', 'company', 'location', 'reviews', 'summary', 'salary'])

# %%
df.shape
# Out:
# (748, 6)

# %% [raw]
# df.salary.unique()

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %%
df['hourly'] = df['salary'].map(lambda x: 1 if 'hour' in x else 0)

# %%
df['monthly'] = df['salary'].map(lambda x: 1 if 'month' in x else 0)

# %%
df['yearly'] = df['salary'].map(lambda x: 1 if 'year' in x else 0)

# %%
df[df['hourly'] == 1]
# Out:
#                                    title         company    location reviews  \
# 229  Forensic Scientist-DNA (8 Openings)  City of Austin  Austin, TX      85
#
#                                                summary  \
# 229  Skill in data analysis and problem solving. Gr...
#
#                       salary  hourly  monthly  yearly
# 229  $23.44 - $29.80 an hour       1        0       0

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import numpy as np

# %%
## YOUR CODE HERE
def get_salary_amount(salary_string):
    try:
        salary_string.replace('-', ' ')
        sal_list = salary_string.split()
        figures = []
        for i in sal_list:
            try:
#                 print i.strip('$')
                figures.append(float(i.strip('$').replace(',','')))
            except:
                pass
#         print figures
        return (np.mean(figures))
    except:
        return np.nan

# %%
df[df['salary'] != '']
# Out:
#                                                  title  \
# 159                                Statistical Analyst
# 161     Microbiology Supervisor / MLS Program Director
# 162  Research Engineering/ Scientist Associate II -...
# 169  Engineering Scientist Associate - R and D Soft...
# 172       Research Engineering/ Scientist Associate II
# 173                                 Linkage Specialist
# 174                         Senior Statistical Analyst
# 177             Senior Machine Learning Data Scientist
# 183  Engineering Scientist Associate - Remote Sensi...
# 185  Research Engineering/ Scientist Associate III ...
# 192  Engineering Scientist - R and D Data Analysis ...
# 200           Engineering Scientist - GPS Data Analyst
# 203                          THP Statistician II, HSOC
# 206  Engineering Scientist Associate - System Suppo...
# 219                          Machine Learning Engineer
# 229                Forensic Scientist-DNA (8 Openings)
# 231                 Senior Software Engineer/Team Lead
# 246  Research Engineering/ Scientist Associate III ...
# 287  Engineering Scientist - Geospatial Application...
# 291  Forensic Scientist I-III (Forensic Document Ex...
# 294  Engineering Scientist Associate - Underwater R...
# 302                     Health Scientist (Informatics)
# 321                                Lead Data Scientist
# 325                          Mathematical Statistician
# 332                                     Epidemiologist
# 348            Business Research Analyst - Entry Level
# 367                              Senior Data Scientist
# 393                          Lead Quantitative Analyst
# 426                            Senior R&D Statistician
# 485              Senior Machine Learning Data Engineer
# 486                               Quantitative Analyst
# 503                                   Research Analyst
# 515                  Data Scientist / Python Developer
# 520                                 RESEARCH SCIENTIST
# 542                                       DATA ANALYST
# 543  Coordinator / Lead Scientist, Municipal Storm ...
# 546         Quantitative Analyst for Global Quant Fund
# 558                                          Ecologist
# 561  Recruitment Coordinator, World Trade Center He...
# 565                     Senior / Director Data Science
# 571  Data Analyst, Bureau of Veterinary and Pest Co...
# 574                              Senior Data Scientist
# 580                                Policy Data Analyst
# 586                                Policy Data Analyst
# 589                      Senior Data Scientist (Media)
# 607                Senior Environmental Soil Scientist
# 618                          Academic Python Developer
# 670                      Quantitative Research Analyst
# 683                          Machine Learning Engineer
# 692         Senior Data Scientist (H20, Python, and R)
# 694                          Quantitative Risk Analyst
# 728                                Lead Data Scientist
#
#                                                company  \
# 159                       Health & Human Services Comm
# 161                      Dept of State Health Services
# 162                      University of Texas at Austin
# 169                      University of Texas at Austin
# 172                      University of Texas at Austin
# 173                      Dept of State Health Services
# 174                       Health & Human Services Comm
# 177                                   All-In Analytics
# 183                      University of Texas at Austin
# 185                      University of Texas at Austin
# 192                      University of Texas at Austin
# 200                      University of Texas at Austin
# 203                  Texas Department of Public Safety
# 206                      University of Texas at Austin
# 219                           Volt Workforce Solutions
# 229                                     City of Austin
# 231                                  XOR Data Exchange
# 246                      University of Texas at Austin
# 287                      University of Texas at Austin
# 291                  Texas Department of Public Safety
# 294                      University of Texas at Austin
# 302         Centers for Disease Control and Prevention
# 321                                         Stackfolio
# 325         Centers for Disease Control and Prevention
# 332         Centers for Disease Control and Prevention
# 348                                           CI Radar
# 367                                Analytic Recruiting
# 393                               SearchAccountingJobs
# 426                          Principle Solutions Group
# 485                    DTS - Machine Learning Practice
# 486                                           StreetID
# 503                                      The Real Deal
# 515                        The Hagan-Ricci Group, Inc.
# 520                        HRA/DEPT OF SOCIAL SERVICES
# 542                        HRA/DEPT OF SOCIAL SERVICES
# 543                                  POLICE DEPARTMENT
# 546                                            Averity
# 558                         DEPT OF PARKS & RECREATION
# 561                      DEPT OF HEALTH/MENTAL HYGIENE
# 565                                            Beeswax
# 571                      DEPT OF HEALTH/MENTAL HYGIENE
# 574                                            Averity
# 580                              DEPARTMENT OF FINANCE
# 586                              DEPARTMENT OF FINANCE
# 589                                            Averity
# 607  Metropolitan Water Reclamation District of Gre...
# 618                                 Jobspring Partners
# 670                                  GinasTechJobs.com
# 683                                 Jobspring Partners
# 692                              Workbridge Associates
# 694                Huxley Banking & Financial Services
# 728                                Analytic Recruiting
#
#                                      location reviews  \
# 159                                Austin, TX
# 161                                Austin, TX      18
# 162                                Austin, TX     403
# 169                                Austin, TX     403
# 172                                Austin, TX     403
# 173                                Austin, TX      18
# 174                                Austin, TX
# 177                                Austin, TX
# 183                                Austin, TX     403
# 185                                Austin, TX     403
# 192                                Austin, TX     403
# 200                                Austin, TX     403
# 203                                Austin, TX      98
# 206                                Austin, TX     403
# 219                                Austin, TX   1,512
# 229                                Austin, TX      85
# 231                                Austin, TX
# 246                                Austin, TX     403
# 287                                Austin, TX     403
# 291                                Austin, TX      98
# 294                                Austin, TX     403
# 302                               Atlanta, GA      62
# 321  Atlanta, GA 30308 (Old Fourth Ward area)
# 325                               Atlanta, GA      62
# 332                               Atlanta, GA      62
# 348                              Norcross, GA
# 367                               Atlanta, GA       2
# 393                               Atlanta, GA
# 426                               Roswell, GA       8
# 485                              New York, NY
# 486                              New York, NY
# 503         New York, NY 10001 (Chelsea area)
# 515                              New York, NY
# 520                             Manhattan, NY
# 542                             Manhattan, NY
# 543                              New York, NY      33
# 546                              New York, NY
# 558                             Manhattan, NY
# 561                             Manhattan, NY       5
# 565                              New York, NY
# 571                             Manhattan, NY       5
# 574                              New York, NY
# 580                             Manhattan, NY      66
# 586                             Manhattan, NY      66
# 589                              New York, NY
# 607                               Chicago, IL       7
# 618                               Chicago, IL      12
# 670                               Chicago, IL
# 683                               Chicago, IL      12
# 692                               Chicago, IL      25
# 694                               Chicago, IL
# 728                               Chicago, IL       2
#
#                                                summary  \
# 159  Creation of data appropriate statistical sampl...
# 161  Evaluates and interprets highly complex data. ...
# 162  Contribute to funded research projects enablin...
# 169  Develop algorithms and processing methodologie...
# 172  Proficiency with MS Office Suite and excellent...
# 173  Examples include consulting with other public ...
# 174  Creation of data appropriate statistical sampl...
# 177  Machine Learning Data Scientist. Forecasting, ...
# 183  Employ computational solutions for remote sens...
# 185  Contribute to funded research projects enablin...
# 192  Experience working with data analysis and data...
# 200  Detailed data analyses of GPS observation and ...
# 203  Prepare, compile, test, analyze, and interpret...
# 206  Government globally distributed GPS monitoring...
# 219  Data mining competition experience preferred (...
# 229  Skill in data analysis and problem solving. Gr...
# 231  XOR is leading a data revolution by giving tra...
# 246  Contribute to the development of the GRACE-FO ...
# 287  Lead a small development team in the design, i...
# 291  Forensic Scientist I-III. Ability to present s...
# 294  Demonstrated ability related to data acquisiti...
# 302  As a Health Scientist (Informatics) you will:....
# 321  We are looking for a bright and experienced da...
# 325  Survey designs for related data collection. Co...
# 332  Assessment of the adequacy and quality of data...
# 348  Who We Are CI Radar is the premier provider of...
# 367  Python, data mining, data science; The data Sc...
# 393  The client is looking for talented individuals...
# 426  R&D Statistician to assist with the research a...
# 485  Senior Machine Learning Developer / Data Engin...
# 486  Professional or academic experience working wi...
# 503  Candidates must have an attention to detail an...
# 515  New York City financial services firm is seeki...
# 520  OER also addresses key policy-relevant researc...
# 542  The Data Analyst will:. Experience with data v...
# 543  Maintain records of raw data; Coordinator/Lead...
# 546  Examine and analyze data to increase alpha and...
# 558  Compile and collect baseline data, conduct pre...
# 561  Assist Lead Scientist for Surveys with prepari...
# 565  A minimum of 5 years experience in Machine lea...
# 571  -Tabulating and analyzing field collected data...
# 574  Our data science needs are growing quickly, an...
# 580  Strong data analysis skills and data testing. ...
# 586  Strong data analysis skills and data testing. ...
# 589  We are looking for a Senior Data Scientist exc...
# 607  Collection, analysis, interpretation and prese...
# 618  Is genomic data something that fascinates and ...
# 670  Define and implement data collection and data ...
# 683  We’ve just received our second round of fundin...
# 692  A major Marketing company based in downtown Ch...
# 694  My Client, a leading Global Financial Institut...
# 728  Take analytical objectives and define data req...
#
#                          salary  hourly  monthly  yearly  est_sal
# 159     $4,599 - $6,066 a month       0        1       0      NaN
# 161     $4,500 - $4,900 a month       0        1       0      NaN
# 162              $4,916 a month       0        1       0      NaN
# 169     $5,400 - $6,500 a month       0        1       0      NaN
# 172              $4,000 a month       0        1       0      NaN
# 173     $4,599 - $5,333 a month       0        1       0      NaN
# 174     $5,259 - $6,941 a month       0        1       0      NaN
# 177  $140,000 - $160,000 a year       0        0       1      NaN
# 183     $5,400 - $6,500 a month       0        1       0      NaN
# 185              $5,541 a month       0        1       0      NaN
# 192    $6,250 - $10,833 a month       0        1       0      NaN
# 200    $6,250 - $10,833 a month       0        1       0      NaN
# 203     $3,520 - $4,600 a month       0        1       0      NaN
# 206     $5,400 - $6,500 a month       0        1       0      NaN
# 219  $120,000 - $150,000 a year       0        0       1      NaN
# 229     $23.44 - $29.80 an hour       1        0       0      NaN
# 231              $90,000 a year       0        0       1      NaN
# 246              $4,500 a month       0        1       0      NaN
# 287    $6,250 - $10,833 a month       0        1       0      NaN
# 291     $3,616 - $5,433 a month       0        1       0      NaN
# 294     $5,400 - $6,500 a month       0        1       0      NaN
# 302  $104,349 - $135,656 a year       0        0       1      NaN
# 321              $80,000 a year       0        0       1      NaN
# 325  $104,349 - $135,656 a year       0        0       1      NaN
# 332   $88,305 - $114,802 a year       0        0       1      NaN
# 348    $30,000 - $32,000 a year       0        0       1      NaN
# 367  $100,000 - $125,000 a year       0        0       1      NaN
# 393  $150,000 - $205,000 a year       0        0       1      NaN
# 426             $130,000 a year       0        0       1      NaN
# 485             $200,000 a year       0        0       1      NaN
# 486             $120,000 a year       0        0       1      NaN
# 503              $40,000 a year       0        0       1      NaN
# 515  $200,000 - $300,000 a year       0        0       1      NaN
# 520    $70,286 - $85,664 a year       0        0       1      NaN
# 542    $57,969 - $62,000 a year       0        0       1      NaN
# 543   $78,630 - $103,332 a year       0        0       1      NaN
# 546  $150,000 - $300,000 a year       0        0       1      NaN
# 558    $70,286 - $80,000 a year       0        0       1      NaN
# 561    $70,286 - $88,213 a year       0        0       1      NaN
# 565  $130,000 - $165,000 a year       0        0       1      NaN
# 571    $57,969 - $70,142 a year       0        0       1      NaN
# 574  $125,000 - $175,000 a year       0        0       1      NaN
# 580    $68,239 - $80,000 a year       0        0       1      NaN
# 586    $68,239 - $80,000 a year       0        0       1      NaN
# 589             $150,000 a year       0        0       1      NaN
# 607   $93,257 - $137,114 a year       0        0       1      NaN
# 618   $75,000 - $100,000 a year       0        0       1      NaN
# 670             $180,000 a year       0        0       1      NaN
# 683  $100,000 - $120,000 a year       0        0       1      NaN
# 692  $110,000 - $155,000 a year       0        0       1      NaN
# 694             $110,000 a year       0        0       1      NaN
# 728             $140,000 a year       0        0       1      NaN

# %%
df.ix[159,'salary']
# Out:
# u'$4,599 - $6,066 a month'

# %%
get_salary_amount(df.ix[159,'salary'])
# Out:
# 5332.5

# %%
df['est_sal'] = df['salary'].map(get_salary_amount)

# %%
df.head()
# Out:
#                                                title   company  \
# 0                   Save lives with machine learning  Blue Owl
# 1                  Save lives as a software engineer  Blue Owl
# 2                              Senior Data Scientist  Stem Inc
# 3  Machine Learning Deployment Engineer, Professi...    Google
# 4                                      Data Engineer  Opendoor
#
#                      location reviews  \
# 0           San Francisco, CA
# 1           San Francisco, CA
# 2  San Francisco Bay Area, CA
# 3           San Francisco, CA   1,216
# 4           San Francisco, CA       2
#
#                                              summary salary  hourly  monthly  \
# 0  Requirements for all data scientists. Expert i...              0        0
# 1  Experience working closely with data scientist...              0        0
# 2  As a Data Scientist at Stem, you’ll be working...              0        0
# 3  Experience interpreting technical data and cre...              0        0
# 4  Collaborate with Data Scientists to derive fea...              0        0
#
#    yearly  est_sal
# 0       0      NaN
# 1       0      NaN
# 2       0      NaN
# 3       0      NaN
# 4       0      NaN

# %%
df.describe()
# Out:
#            hourly     monthly      yearly        est_sal
# count  748.000000  748.000000  748.000000      52.000000
# mean     0.001337    0.022727    0.045455   78826.204231
# std      0.036564    0.149132    0.208438   67066.369857
# min      0.000000    0.000000    0.000000      26.620000
# 25%      0.000000    0.000000    0.000000    5950.000000
# 50%      0.000000    0.000000    0.000000   78612.250000
# 75%      0.000000    0.000000    0.000000  122501.875000
# max      1.000000    1.000000    1.000000  250000.000000

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %%
df2 = df.copy()
df2 = df2.drop('salary', axis=1)

# %%
df2.to_csv('indeed.csv', encoding='utf-8')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2.est_sal.hist()

# %%
driver2 = webdriver.PhantomJS(executable_path=path_phantom)

# %%
linkedin_url = 'https://www.linkedin.com/jobs/search?keywords=Data+Scientist&locationId=STATES.us.ny&start={}&count=25&trk=jobs_jserp_pagination_next'

# %%
driver2.get(linkedin_url.format(0))

# %% [markdown]
# https://www.linkedin.com/jobs/search?keywords=Data+Scientist&locationId=STATES.us.ny&start=25&count=25&trk=jobs_jserp_pagination_next

# %%
soup2 = BeautifulSoup(driver2.page_source, 'lxml')

# %%
print soup2.prettify()
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en" class="ie ie6 lte9 lte8 lte7 os-mac"> <![endif]-->
# <!--[if IE 7]> <html lang="en" class="ie ie7 lte9 lte8 lte7 os-mac"> <![endif]-->
# <!--[if IE 8]> <html lang="en" class="ie ie8 lte9 lte8 os-mac"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie ie9 lte9 os-mac"> <![endif]-->
# <!--[if gt IE 9]> <html lang="en" class="os-mac"> <![endif]-->
# <!--[if !IE]><!-->
# <html class="os-mac" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Data Scientist Jobs in New York | LinkedIn
#   </title>
#   <meta content="origin" name="referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="af2eb8ea-4900-4c0b-aaa5-7038b35cb63e" name="pageImpressionID"/>
#   <meta content="chrome" name="appName"/>
#   <meta content="6X0rbKC+fRSAnUlN9SoAAA==" name="treeID"/>
#   <meta content="//www.linkedin.com/mob/tracking" name="globalTrackingUrl"/>
#   <meta content="chrome" name="globalTrackingAppName"/>
#   <meta content="webTracking" name="globalTrackingAppId"/>
#   <!--[if lte IE 8]>
#   <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/16x16/favicon.ico">
# <![endif]-->
#   <!--[if IE 9]>
#   <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico">
# <![endif]-->
#   <link href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" rel="icon"/>
#   <link href="https://static.licdn.com/scds/common/u/img/icon/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png" name="msapplication-TileImage"/>
#   <meta content="#0077B5" name="msapplication-TileColor"/>
#   <meta content="LinkedIn" name="application-name"/>
#  </head>
#  <body>
#   <p>
#    <meta content="https://static.licdn.com/scds/concat/common/js?v=build-2000_8_58811-prod" name="RemoteNavJSContentBaseURL"/>
#    <script async="" src="//platform.linkedin.com/js/analytics.js">
#    </script>
#    <script src="https://static.licdn.com/scds/concat/common/js?h=7ndrn0f9fw0hum7uoqcjcnzne-95d8d303rtd0n9wj4dcjbnh2c-7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript">
#    </script>
#    <link href="https://static.licdn.com/scds/concat/common/css?h=8y3ci1woohhv06fw52drr3bu1-a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#    <script>
#    </script>
#    <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#    <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#    <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#    <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript">
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.367/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js">
#    </script>
#    <link href="//static.licdn.com" rel="preconnect"/>
#    <link href="//media.licdn.com" rel="preconnect"/>
#    <link href="//platform.linkedin.com" rel="preconnect"/>
#    <link href="https://www.linkedin.com/jobs/data-scientist-jobs-new-york" rel="canonical"/>
#    <link href="android-app://com.linkedin.android.jobs.jobseeker/https/www.linkedin.com/jobs/data-scientist-jobs-new-york" rel="alternate"/>
#    <meta content="www.linkedin.com/jobs/data-scientist-jobs-new-york" property="og:url"/>
#    <meta content="www.linkedin.com/jobs/data-scientist-jobs-new-york" property="og:appindexUrl"/>
#    <meta content="Data Scientist Jobs in New York" property="og:title"/>
#    <meta content="Apply to 744 Data Scientist jobs in New York on LinkedIn. Sign-up today, leverage your professional network, and get hired. New Data Scientist jobs added daily." property="og:description"/>
#    <meta content="LinkedIn" property="og:site_name"/>
#    <meta content="index, follow, noarchive" name="robots"/>
#    <meta content="app-id=886051313, app-argument=lijobseeker://search?smartbanner=1&amp;logged_in=0" name="apple-itunes-app"/>
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <meta content="play streaming enabled" name="play-streaming"/>
#    <meta content="Apply to 744 Data Scientist jobs in New York on LinkedIn. Sign-up today, leverage your professional network, and get hired. New Data Scientist jobs added daily." name="description"/>
#    <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.367/f/%2Fjobs-frontend%2Fconcat%2Fjserp-style-dependencies_en_US.css" rel="stylesheet"/>
#    <meta content="d_jobs_jserp_guest" name="pageKey"/>
#    <style>
#     /* Regular */
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-weight: normal;
#   font-style: normal;
#   src: url(data:font/truetype;charset=utf-8;base64,...) format('truetype');
# }
# /* Thin */
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-weight: 300;
#   font-style: normal;
#   src: url(data:font/truetype;charset=utf-8;base64,...) format('truetype');
# }
# /* Semibold */
# @font-face {
#   font-family: 'Source Sans Pro';
#   font-weight: 700;
#   font-style: normal;
#   src: url(data:font/truetype;charset=utf-8;base64,...) format('truetype');
# }
#    </style>
#   </p>
#   <svg height="264px" id="svg-source" style="position: fixed; top: -999px; left: -999px; display: none;" version="1.1" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#    <style>
#     use{
#       fill-opacity: 1;
#       stroke-opacity: 1;
#       fill: transparent;
#       stroke: transparent;
#     }
#     use[data-size=small], .active use[*|href^="#nav-"], use[data-state=active], li-icon[size=small], li-icon[type^="nav-"][active]{
#       fill-opacity: 0;
#       stroke-opacity: 0;
#       fill: currentColor;
#       stroke: currentColor;
#     }
#
#     @-webkit-keyframes loaderspin {
#       from { -webkit-transform: rotate(0deg) translate(-30px, -30px);}
#       to { -webkit-transform: rotate(360deg) translate(-30px, -30px);}
#     }
#     @keyframes loaderspin {
#       from {
#         -webkit-transform: rotate(0deg) translate(-30px, -30px);
#         transform: rotate(0deg) translate(-30px, -30px);
#       }
#       to {
#         -webkit-transform: rotate(360deg) translate(-30px, -30px);
#         transform: rotate(360deg) translate(-30px, -30px);
#       }
#     }
#
#     li-icon[type=loader] &gt; svg {
#       -webkit-transform-origin: 50% 50%;
#       transform-origin: 50% 50%;
#
#       -webkit-animation: loaderspin 1s steps(12) infinite;
#       -moz-animation: loaderspin 1s steps(12) infinite;
#       -o-animation: loaderspin 1s steps(12) infinite;
#       -ms-animation: loaderspin 1s steps(12) infinite;
#       animation: loaderspin 1s steps(12) infinite;
#     }
#
#     li-icon {
#       display: inline-block;
#       width: 300px;
#       height: 150px;
#       overflow: hidden;
#     }
#     li-icon[type$="-icon"]{
#       fill-opacity: 1;
#       stroke-opacity: 1;
#       fill: transparent;
#       stroke: transparent;
#       width: 24px;
#       height: 24px;
#     }
#     li-icon[type$="-icon"][size="small"] {
#       fill-opacity: 0;
#       stroke-opacity: 0;
#       fill: currentColor;
#       stroke: currentColor;
#       width: 16px;
#       height: 16px;
#     }
#     li-icon[type="loader"]{
#       fill-opacity: 1;
#       stroke-opacity: 1;
#       fill: transparent;
#       stroke: transparent;
#     }
#     li-icon[type="loader"][size="small"]{
#       fill-opacity: 0;
#       stroke-opacity: 0;
#       fill: currentColor;
#       stroke: currentColor;
#     }
#     li-icon g[id*=_color],
#     li-icon g[id*=-color] {
#       display: none;
#     }
#     li-icon[color] g[id*=_solid],
#     li-icon[color] g[id*=-solid] {
#       display: none;
#     }
#     li-icon[color] g[id*=_color],
#     li-icon[color] g[id*=-color] {
#       display: block;
#     }
#     li-icon[type^="nav-"]{
#       width: 32px;
#       height: 32px;
#     }
#
#     li-icon[type^="large-"], li-icon[type^="large-"][size="small"]{
#       width: 48px;
#       height: 48px;
#     }
#    </style>
#    <defs id="ui-icons">
#     <svg height="24px" id="analytics-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M4,12h10v2H3c-0.552,0-1-0.448-1-1V2h2V12zM13.268,2c-0.141,0-0.286,0.033-0.42,0.118l-2.594,1.646L11.4,4.368L9.927,7.223l-2.209-1.13C7.519,5.99,7.282,5.972,7.066,6.042c-0.215,0.07-0.394,0.224-0.495,0.427l-1.831,3.65l1.52,0.762l1.447-2.885l2.2,1.126c0.418,0.214,0.928,0.049,1.142-0.367l1.805-3.645L14,5.737V2.751C14,2.319,13.656,2,13.268,2z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M5,19h16v2H5c-1.105,0-2-0.896-2-2V3h2V19zM20,3c-0.185,0-0.375,0.052-0.55,0.167L15,6l2.245,1.216l-2.661,4.923l-3.634-1.984c-0.2-0.108-0.435-0.133-0.651-0.068c-0.217,0.065-0.399,0.215-0.506,0.415l-3.069,5.763l1.5,0.799l2.666-5.005l3.629,1.982c0.199,0.108,0.433,0.134,0.648,0.069c0.217-0.064,0.399-0.212,0.507-0.411l3.067-5.672L21,9.25V4.002C21,3.415,20.519,3.001,20,3z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="archive-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,2H8L7.5,1H2C1.448,1,1,1.448,1,2v10c0,0.552,0.448,1,1,1h12c0.552,0,1-0.448,1-1V3C15,2.448,14.552,2,14,2z M13,11H2.994L2.992,3l0.002,0H3h3.514L7,3.972V7H5l2.24,2.651C7.44,9.884,7.72,10,8,10c0.28,0,0.559-0.117,0.759-0.349L11,7H9V4h4V11z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,5h-8l-1-2H4C2.896,3,2,3.895,2,5v13c0,1.105,0.896,2,2,2h16c1.104,0,2-0.895,2-2V7C22,5.895,21.104,5,20,5z M20,18H3.994L3.992,5l0.002,0H4h6.014L11,6.972v6.347l-2.763-2.772L7,11.784l3.656,3.656C11.027,15.811,11.513,16,12,16s0.973-0.189,1.344-0.56L17,11.783l-1.237-1.237L13,13.318V7h7V18z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="arrow-down-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M2,9.821l1.145-1.145L7,12.519V2h2v10.519l3.855-3.843L14,9.821l-4.657,4.623C8.972,14.815,8.486,15,8,15c-0.486,0-0.972-0.186-1.343-0.557L2,9.821z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M10.656,21.44L3,13.761l1.237-1.237L11,19.319V3h2v16.318l6.796-6.783l1.214,1.237l-7.667,7.667C12.972,21.811,12.486,22,12,22S11.027,21.811,10.656,21.44z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="arrow-left-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,9H3.481l3.843,3.855L6.179,14L1.557,9.343C1.186,8.972,1,8.486,1,8c0-0.486,0.186-0.972,0.557-1.343L6.179,2l1.145,1.145L3.481,7H14V9z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M21,13H4.682l6.783,6.796l-1.237,1.214L2.56,13.343C2.189,12.972,2,12.486,2,12s0.189-0.973,0.56-1.344L10.239,3l1.237,1.237L4.681,11H21V13z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="arrow-right-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,8c0,0.486-0.186,0.972-0.557,1.343L10,14l-1.324-1.145L12.519,9H2V7h10.519L8.676,3.145L9.821,2l4.623,4.657C14.814,7.028,15,7.514,15,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M22,12c0,0.486-0.189,0.973-0.56,1.344L13.761,21l-1.237-1.237L19.319,13H3v-2h16.318l-6.783-6.796l1.237-1.214l7.667,7.667C21.811,11.028,22,11.514,22,12z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="arrow-up-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,6.179l-1.145,1.145L9,3.481V14H7V3.481L3.145,7.324L2,6.179l4.657-4.623C7.028,1.185,7.514,1,8,1c0.486,0,0.972,0.186,1.343,0.557L14,6.179z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M13.344,2.56L21,10.239l-1.237,1.237L13,4.681V21h-2V4.682l-6.796,6.783L2.99,10.227l7.667-7.667C11.028,2.189,11.514,2,12,2S12.973,2.189,13.344,2.56z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="arrow-up-left-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M5.4,4H11V2H4.016C3.465,2,2.966,2.223,2.604,2.584c-0.362,0.361-0.586,0.86-0.587,1.411L2,11h2V5.403L12.6,14l1.4-1.394L5.4,4z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,18.6L7.4,6H17V4H6C5.448,4,4.948,4.224,4.586,4.586C4.224,4.948,4,5.448,4,6v11h2V7.409L18.6,20L20,18.6z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="at-pebble-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8,1C4.14,1,1,4.14,1,8s3.14,7,7,7h3v-2H8c-2.757,0-5.125-2.243-5.125-5S5.243,2.875,8,2.875S13,5.243,13,8c0,0.551-0.449,1-1,1h-1V8c0-1.654-1.346-3-3-3S5,6.346,5,8s1.346,3,3,3h4c1.654,0,3-1.346,3-3C15,4.14,11.86,1,8,1zM6.875,8c0-0.625,0.484-1.125,1.125-1.125c0.625,0,1,0.469,1,1.125v1H8C7.344,9,6.875,8.609,6.875,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M12,2C6.486,2,2,6.486,2,12s4.486,10,10,10h5v-2h-5c-4.411,0-8.125-3.589-8.125-8c0-4.531,3.594-8.125,8.125-8.125c4.562,0,8,3.594,8,8.125v1.5c0,0.969-0.547,1.5-1.5,1.5H17v-3c0-2.757-2.243-5-5-5s-5,2.243-5,5s2.243,5,5,5h6.5c1.859,0,3.5-1.656,3.5-3.5V12C22,6.486,17.514,2,12,2zM8.875,12c0-1.75,1.375-3.125,3.125-3.125c1.792,0,3,1.354,3,3.125v3h-3C10.346,15,8.875,13.654,8.875,12z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="bell-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M12,9V6c0-2.209-1.791-4-4-4S4,3.791,4,6v3c0,1.104-0.895,2-2,2v2h4c0,1.104,0.895,2,2,2s2-0.896,2-2h4v-2C12.895,11,12,10.104,12,9zM5.213,11C5.703,10.484,6,9.728,6,9V5.875c0-1.103,0.897-2,2-2s2,0.897,2,2V9c0,0.728,0.281,1.484,0.834,2H5.213z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M18,15V9c0-3.314-2.686-6-6-6S6,5.686,6,9v6c0,1.657-1.343,3-3,3v2h7c0,1.104,0.895,2,2,2s2-0.896,2-2h7v-2C19.343,18,18,16.657,18,15zM6.998,18C7.627,17.164,8,16.125,8,15V8.875c0-2.206,1.794-4,4-4s4,1.794,4,4V15c0,1.125,0.373,2.164,1.002,3H6.998z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="block-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8,1C4.134,1,1,4.134,1,8c0,3.866,3.134,7,7,7c3.866,0,7-3.134,7-7C15,4.134,11.866,1,8,1zM2.77,8c0-2.884,2.346-5.23,5.23-5.23c1.123,0,2.158,0.363,3.011,0.967l-7.273,7.273C3.133,10.158,2.77,9.123,2.77,8zM8,13.23c-1.123,0-2.158-0.363-3.011-0.967l7.273-7.273C12.867,5.842,13.23,6.877,13.23,8C13.23,10.884,10.884,13.23,8,13.23z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M12,2C6.477,2,2,6.477,2,12c0,5.523,4.477,10,10,10c5.523,0,10-4.477,10-10C22,6.477,17.523,2,12,2zM3.77,12c0-4.538,3.692-8.23,8.23-8.23c1.951,0,3.742,0.685,5.154,1.824L5.594,17.154C4.455,15.742,3.77,13.951,3.77,12zM12,20.23c-1.951,0-3.742-0.685-5.154-1.824L18.406,6.846C19.545,8.258,20.23,10.049,20.23,12C20.23,16.538,16.538,20.23,12,20.23z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="briefcase-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,5h-2V3c0-0.552-0.448-1-1-1H5C4.448,2,4,2.448,4,3l0,2H2C1.448,5,1,5.448,1,6v7c0,0.552,0.448,1,1,1h12c0.552,0,1-0.448,1-1V6C15,5.448,14.552,5,14,5zM6,4h4v1H6V4zM13,12H3V7h10V12z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,7h-3l0-2c0-1.105-0.895-2-2-2H9C7.895,3,7,3.895,7,5l0,2H4C2.895,7,2,7.895,2,9v9c0,1.105,0.895,2,2,2h16c1.105,0,2-0.895,2-2V9C22,7.895,21.105,7,20,7zM9,5h6l0,2H9V5zM20,18H4V9h16V18z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="calendar-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M13,4h-1V2h-2v2H6V2H4v2H3C2.448,4,2,4.448,2,5v8c0,0.552,0.448,1,1,1h7.125L14,10.104V5C14,4.448,13.552,4,13,4zM12,9H9v3H4V6h8V9z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M19,6h-2V3h-2v3H9V3H7v3H5C3.895,6,3,6.895,3,8v11c0,1.105,0.895,2,2,2h10.125L21,15.125V8C21,6.895,20.105,6,19,6zM19,14h-5v5H5V8h1.979v2h2V8h6v2h2V8H19V14z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="camera-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,4h-1.5l-1-2h-7l-1,2H2C1.448,4,1,4.448,1,5v7c0,0.552,0.448,1,1,1h12c0.552,0,1-0.448,1-1V5C15,4.448,14.552,4,14,4zM13,11H3V6h1.736l1-2h4.528l1,2H13V11zM10,8c0,1.105-0.895,2-2,2S6,9.105,6,8s0.895-2,2-2S10,6.895,10,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,6h-2l-1.5-3h-9L6,6H4C2.895,6,2,6.895,2,8v10c0,1.105,0.895,2,2,2h16c1.105,0,2-0.895,2-2l0-10C22,6.895,21.105,6,20,6zM20,18H4V8h3.236l1.5-3h6.528l1.5,3H20V18zM12,7c-2.761,0-5,2.239-5,5c0,2.761,2.239,5,5,5c2.761,0,5-2.239,5-5C17,9.239,14.761,7,12,7zM12,15.125c-1.723,0-3.125-1.402-3.125-3.125c0-1.723,1.402-3.125,3.125-3.125s3.125,1.402,3.125,3.125C15.125,13.723,13.723,15.125,12,15.125z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="cancel-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M12.99,4.248L9.237,8L13,11.763L11.763,13L8,9.237L4.237,13L3,11.763L6.763,8L3,4.237L4.237,3L8,6.763l3.752-3.752L12.99,4.248z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,5.237l-6.763,6.768l6.743,6.747l-1.237,1.237L12,13.243L5.257,19.99l-1.237-1.237l6.743-6.747L4,5.237L5.237,4L12,10.768L18.763,4L20,5.237z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="check-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M13.605,2.021L15,3.077L7.184,13.401C6.888,13.796,6.445,13.996,6.001,14c-0.455,0.005-0.911-0.195-1.215-0.599L1,8.391l1.387-1.067l3.6,4.76L13.605,2.021z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M19.605,4L21,5.057L10.184,19.401C9.888,19.796,9.445,19.996,9.001,20c-0.455,0.005-0.911-0.195-1.215-0.599L3,13.067L4.387,12l4.6,6.084L19.605,4z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="chevron-down-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,6.442l-6.126,4.278C8.612,10.906,8.306,11,8,11c-0.306,0-0.612-0.094-0.873-0.281L1,6.442L1.991,5L8,9.196L14.008,5L15,6.442z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M21.996,9.446l-9.118,6.278c-0.261,0.187-0.568,0.281-0.874,0.281c-0.306,0-0.612-0.094-0.873-0.281L2.004,9.446l0.991-1.442l9.009,6.196l9-6.196L21.996,9.446z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="chevron-left-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M11,1.992L6.804,8L11,14.009L9.558,15L5.281,8.874C5.094,8.613,5,8.306,5,8c0-0.306,0.094-0.613,0.281-0.874L9.558,1L11,1.992z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M16,3l-6.196,9L16,21.009L14.558,22l-6.277-9.126C8.094,12.613,8,12.306,8,12c0-0.306,0.094-0.613,0.281-0.874l6.278-9.118L16,3z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="chevron-right-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M6.442,1l4.278,6.126C10.906,7.388,11,7.694,11,8c0,0.306-0.094,0.612-0.281,0.873L6.442,15L5,14.009L9.196,8L5,1.992L6.442,1z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M9.442,2.008l6.278,9.118C15.906,11.388,16,11.694,16,12c0,0.306-0.094,0.612-0.281,0.873L9.442,22L8,21.009L14.196,12L8,3L9.442,2.008z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="chevron-up-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14.008,11L8,6.804L1.991,11L1,9.558l6.126-4.277C7.387,5.094,7.694,5,8,5c0.306,0,0.613,0.094,0.874,0.281L15,9.558L14.008,11z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M21.004,16.004l-9-6.196l-9.009,6.196l-0.991-1.442l9.126-6.277c0.261-0.187,0.567-0.281,0.873-0.281c0.306,0,0.613,0.094,0.874,0.281l9.118,6.278L21.004,16.004z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="circle-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,8c0,3.866-3.134,7-7,7c-3.866,0-7-3.134-7-7c0-3.866,3.134-7,7-7C11.866,1,15,4.134,15,8zM13.23,8c0-2.884-2.346-5.23-5.23-5.23C5.116,2.77,2.77,5.116,2.77,8c0,2.884,2.346,5.23,5.23,5.23C10.884,13.23,13.23,10.884,13.23,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M22,12c0,5.523-4.477,10-10,10C6.477,22,2,17.523,2,12C2,6.477,6.477,2,12,2C17.523,2,22,6.477,22,12zM20.23,12c0-4.538-3.692-8.23-8.23-8.23c-4.538,0-8.23,3.692-8.23,8.23s3.692,8.23,8.23,8.23C16.538,20.23,20.23,16.538,20.23,12z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="clipboard-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M12,2H9.288L9.064,1.553C8.895,1.214,8.549,1,8.17,1H7.83C7.451,1,7.105,1.214,6.936,1.553L6.712,2H4C3.448,2,3,2.448,3,3v11c0,0.552,0.448,1,1,1h8c0.552,0,1-0.448,1-1V3C13,2.448,12.552,2,12,2zM11,13H5V4h1l0.25,1h3.5L10,4h1V13z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M18,4h-3.664l-0.585-1.171C13.497,2.321,12.977,2,12.409,2h-0.818c-0.568,0-1.088,0.321-1.342,0.829L9.664,4H6C4.895,4,4,4.895,4,6v14c0,1.105,0.895,2,2,2h12c1.105,0,2-0.895,2-2V6C20,4.895,19.105,4,18,4zM18,20H6V6h2l0.5,2h7L16,6h2V20z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="clipboard-add-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M5,12h3v2H4c-0.552,0-1-0.448-1-1V3c0-0.552,0.448-1,1-1h2.712l0.224-0.447C7.105,1.214,7.451,1,7.83,1h0.34c0.379,0,0.725,0.214,0.894,0.553L9.288,2H12c0.552,0,1,0.448,1,1v6h-2V4h-1L9.75,5h-3.5L6,4H5V12zM13,12v-2h-2v2H9v2h2v2h2v-2h2v-2H13z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M6,19h7v2H6c-1.105,0-2-0.895-2-2V6c0-1.105,0.895-2,2-2h3.664l0.585-1.171C10.503,2.321,11.023,2,11.591,2h0.818c0.568,0,1.088,0.321,1.342,0.829L14.336,4H18c1.105,0,2,0.895,2,2v8h-2V6h-2l-0.5,2h-7L8,6H6V19zM20,19v-3h-2v3h-3v2h3v3h2v-3h3v-2H20z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="clock-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8.875,7.718L11,9.203l-0.959,1.38L7.55,8.834C7.284,8.647,7.125,8.341,7.125,8.016V4h1.75V7.718zM15,8c0,3.866-3.134,7-7,7c-3.866,0-7-3.134-7-7c0-3.866,3.134-7,7-7C11.866,1,15,4.134,15,8zM13.23,8c0-2.884-2.346-5.23-5.23-5.23C5.116,2.77,2.77,5.116,2.77,8c0,2.884,2.346,5.23,5.23,5.23C10.884,13.23,13.23,10.884,13.23,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M12,2C6.477,2,2,6.477,2,12c0,5.523,4.477,10,10,10c5.523,0,10-4.477,10-10C22,6.477,17.523,2,12,2zM12,20.23c-4.538,0-8.23-3.692-8.23-8.23S7.462,3.77,12,3.77s8.23,3.692,8.23,8.23S16.538,20.23,12,20.23zM12.875,11.718l3.57,2.567l-0.97,1.353l-3.75-2.75c-0.378-0.283-0.6-0.728-0.6-1.2V6h1.75V11.718z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="company-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M10,10H6V8h4V10zM10,5H6v2h4V5zM14,13v2H2v-2h1V3c0-1.105,0.896-2,2-2h6c1.104,0,2,0.895,2,2v10H14zM5,13h2v-1h2v1h2V3H5V13z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M15,16H9v-2h6V16zM15,10H9v2h6V10zM15,6H9v2h6V6zM21,20v2H3v-2h2V4c0-1.105,0.896-2,2-2h10c1.104,0,2,0.895,2,2v16H21zM7,20h4v-2h2v2h4V4H7V20z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="compass-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8,1C4.134,1,1,4.134,1,8s3.134,7,7,7s7-3.134,7-7S11.866,1,8,1zM8,13.25c-2.895,0-5.25-2.355-5.25-5.25S5.105,2.75,8,2.75S13.25,5.105,13.25,8S10.895,13.25,8,13.25zM7.456,6.507L10,5L9.587,7.912C9.548,8.238,9.433,8.551,9.252,8.826S8.829,9.329,8.544,9.493L6,11l0.413-2.912c0.039-0.326,0.154-0.639,0.335-0.914S7.171,6.671,7.456,6.507z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M9.495,10.349c-0.362,0.549-0.591,1.175-0.669,1.828L8,18l5.089-3.013c0.569-0.329,1.054-0.786,1.416-1.336s0.591-1.175,0.669-1.828L16,6l-5.089,3.013C10.342,9.343,9.857,9.8,9.495,10.349zM11.803,10.519l1.953-1.156l-0.319,2.252c-0.046,0.381-0.181,0.752-0.393,1.073s-0.499,0.592-0.847,0.793l-1.953,1.156l0.319-2.252c0.046-0.381,0.181-0.752,0.393-1.073S11.455,10.72,11.803,10.519zM12,2C6.477,2,2,6.477,2,12s4.477,10,10,10s10-4.477,10-10S17.523,2,12,2zM12,20.25c-4.549,0-8.25-3.701-8.25-8.25S7.451,3.75,12,3.75s8.25,3.701,8.25,8.25S16.549,20.25,12,20.25z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="compose-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M11,8.75l2-2V13c0,0.55-0.45,1-1,1H3c-0.55,0-1-0.45-1-1V4c0-0.55,0.45-1,1-1h6.25l-2,2H4v7h7V8.75zM13.854,2.854l-0.707-0.707C13.049,2.049,12.92,2,12.792,2c-0.128,0-0.255,0.049-0.353,0.146L6,8.586L5,11l2.414-1l6.439-6.439C13.951,3.463,14,3.334,14,3.206C14,3.079,13.951,2.951,13.854,2.854z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M17,13.75l2-2V19c0,1.1-0.9,2-2,2H5c-1.1,0-2-0.9-2-2V7c0-1.1,0.9-2,2-2h7.25l-2,2H5v12h12V13.75zM20.999,6.707c0,0.284-0.089,0.536-0.292,0.74L13.154,15L7,17l2-6.154l7.553-7.553C16.748,3.098,17.004,3,17.26,3s0.512,0.098,0.707,0.293l2.74,2.74C20.894,6.22,20.999,6.462,20.999,6.707zM18.907,6.74L17.26,5.093l-7.069,7.069l1.647,1.647L18.907,6.74z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="connect-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M9.78,8.943L8,8.312V7.846C8.61,7.297,9,6.51,9,5.625V4c0-1.657-1.343-3-3-3S3,2.343,3,4v1.625C3,6.51,3.39,7.297,4,7.846v0.466l-1.78,0.63C0.89,9.414,0,10.673,0,12.085V14h12v-1.915C12,10.673,11.11,9.414,9.78,8.943zM5,3.5c0-0.551,0.449-1,1-1s1,0.449,1,1v3c0,0.551-0.449,1-1,1s-1-0.449-1-1V3.5zM10.125,12h-8.25v-0.412c0-0.471,0.307-0.823,0.709-0.965L6,9.413l3.416,1.21c0.402,0.142,0.709,0.494,0.709,0.965V12zM16,5v2h-2v2h-2V7h-2V5h2V3h2v2H16z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M15.669,13.945L13,13v-1.379c0.615-0.703,1-1.613,1-2.621V6c0-2.209-1.791-4-4-4S6,3.791,6,6v3c0,1.008,0.385,1.917,1,2.62V13l-2.669,0.945C2.334,14.652,1,16.541,1,18.659V21h18v-2.341C19,16.541,17.666,14.652,15.669,13.945zM8,5.75c0-1.103,0.897-2,2-2s2,0.897,2,2v3.5c0,1.103-0.897,2-2,2s-2-0.897-2-2V5.75zM17.125,19H2.875v-0.591c0-1.271,0.801-2.404,1.999-2.828L9,14.163v-1.305C9.321,12.942,9.653,13,10,13s0.679-0.058,1-0.141v1.305l4.126,1.417c1.198,0.424,1.999,1.557,1.999,2.828V19zM24,8v2h-3v3h-2v-3h-3V8h3V5h2v3H24z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="document-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M9.125,1H4C3.448,1,3,1.448,3,2v12c0,0.552,0.448,1,1,1h8c0.552,0,1-0.448,1-1V4.896L9.125,1zM5,13V3h3v3h3v7H5z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M14.125,2H6C4.895,2,4,2.895,4,4v16c0,1.105,0.895,2,2,2h12c1.105,0,2-0.895,2-2V7.875L14.125,2zM6,20V4h7v5h5v11H6z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="download-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,10v3c0,0.552-0.448,1-1,1H3c-0.552,0-1-0.448-1-1v-3h2v2h8v-2H14zM8,10c0.486,0,0.973-0.185,1.344-0.557L12,6.787l-1.145-1.145L9,7.519V1H7v6.519L5.145,5.642L4,6.786l2.656,2.657C7.027,9.814,7.513,10,8,10z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M21,15v4c0,1.105-0.895,2-2,2H5c-1.105,0-2-0.895-2-2v-4h2v4h14v-4H21zM12,16c0.486,0,0.972-0.189,1.343-0.56L18,10.783l-1.237-1.237L13,13.318V2h-2v11.319L7.237,9.547L6,10.784l4.656,4.656C11.027,15.811,11.513,16,12,16z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="ellipsis-horizontal-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M4,7v2H2V7H4zM7,7v2h2V7H7zM12,7v2h2V7H12z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M6,10v4H2v-4H6zM10,10v4h4v-4H10zM18,10v4h4v-4H18z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="ellipsis-vertical-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M9,4H7V2h2V4zM9,7H7v2h2V7zM9,12H7v2h2V12z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M14,6h-4V2h4V6zM14,10h-4v4h4V10zM14,18h-4v4h4V18z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="envelope-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,3H2C1.448,3,1,3.448,1,4v8c0,0.552,0.448,1,1,1h12c0.552,0,1-0.448,1-1V4C15,3.448,14.552,3,14,3zM12.373,5L8,8.296L3.625,5H12.373zM3,11V6.747l3.809,2.857C7.162,9.867,7.581,9.999,7.999,10c0.42,0.001,0.839-0.13,1.194-0.393L13,6.768V11H3z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M20,4H4C2.895,4,2,4.895,2,6v12c0,1.105,0.895,2,2,2h16c1.105,0,2-0.895,2-2V6C22,4.895,21.105,4,20,4zM4,6h16v0.262l-8,6.05L4,6.266L4,6zM4,18V8.484l6.809,5.12C11.162,13.867,11.581,13.999,12,14c0.419,0.001,0.839-0.13,1.194-0.393L20,8.517V18H4z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="error-pebble-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M10.916,6.216L9.132,8l1.784,1.784l-1.132,1.132L8,9.132l-1.784,1.784L5.084,9.784L6.918,8L5.084,6.216l1.132-1.132L8,6.868l1.784-1.784L10.916,6.216zM15,8c0,3.866-3.134,7-7,7s-7-3.134-7-7c0-3.866,3.134-7,7-7S15,4.134,15,8zM13.23,8c0-2.884-2.346-5.23-5.23-5.23S2.77,5.116,2.77,8c0,2.884,2.346,5.23,5.23,5.23S13.23,10.884,13.23,8z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M13.238,12l3.463,3.463L15.463,16.7L12,13.237L8.538,16.7L7.3,15.463L10.763,12L7.3,8.537L8.538,7.3L12,10.763l3.452-3.452l1.238,1.237L13.238,12zM22,12c0,5.523-4.477,10-10,10C6.477,22,2,17.523,2,12S6.477,2,12,2C17.523,2,22,6.477,22,12zM20.23,12c0-4.538-3.692-8.23-8.23-8.23S3.77,7.462,3.77,12s3.692,8.23,8.23,8.23S20.23,16.538,20.23,12z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="fast-forward-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15.347,6.767L7,2v3.427L1,2v12l6-3.578V14l8.364-4.987C15.795,8.757,16,8.297,16,7.875C16,7.442,15.775,7.013,15.347,6.767zM3,10.875v-5.75l4,2.318v0.903L3,10.875zM9,10.875v-5.75l4.746,2.75L9,10.875z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M22.347,10.892L11,4v5.467L2,4v16l9-5.435V20l11.364-6.862C22.795,12.882,23,12.422,23,12C23,11.567,22.775,11.138,22.347,10.892zM4,16.625v-9.25l7,4.18v0.89L4,16.625zM13,16.625v-9.25L20.746,12L13,16.625z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="filter-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,2v2H6.723C6.376,4.595,5.738,5,5,5C4.262,5,3.624,4.595,3.277,4H1V2h2.277C3.624,1.405,4.262,1,5,1c0.738,0,1.376,0.405,1.723,1H15zM11,6c-0.738,0-1.376,0.405-1.723,1H1v2h8.277c0.346,0.595,0.984,1,1.723,1c0.738,0,1.376-0.405,1.723-1H15V7h-2.277C12.376,6.405,11.738,6,11,6zM5,11c-0.738,0-1.376,0.405-1.723,1H1v2h2.277C3.624,14.595,4.262,15,5,15c0.738,0,1.376-0.405,1.723-1H15v-2H6.723C6.376,11.405,5.738,11,5,11z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M9.816,5C9.403,3.837,8.304,3,7,3S4.597,3.837,4.184,5H2v2h2.184C4.597,8.163,5.696,9,7,9s2.403-0.837,2.816-2H22V5H9.816zM7,7.4C6.228,7.4,5.6,6.772,5.6,6S6.228,4.6,7,4.6S8.4,5.228,8.4,6S7.772,7.4,7,7.4zM7,15c-1.304,0-2.403,0.837-2.816,2H2v2h2.184C4.597,20.163,5.696,21,7,21s2.403-0.837,2.816-2H22v-2H9.816C9.403,15.837,8.304,15,7,15zM7,19.4c-0.772,0-1.4-0.628-1.4-1.4s0.628-1.4,1.4-1.4s1.4,0.628,1.4,1.4S7.772,19.4,7,19.4zM17,9c-1.304,0-2.403,0.837-2.816,2H2v2h12.184c0.413,1.163,1.512,2,2.816,2s2.403-0.837,2.816-2H22v-2h-2.184C19.403,9.837,18.304,9,17,9zM17,13.4c-0.772,0-1.4-0.628-1.4-1.4s0.628-1.4,1.4-1.4s1.4,0.628,1.4,1.4S17.772,13.4,17,13.4z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="flag-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8.875,4c0-0.552-0.448-1-1-1H4V2H2v12h2v-4h3.125c0,0.552,0.448,1,1,1h4.625L14,4H8.875zM11.346,9H8.875c0-0.552-0.448-1-1-1H4V5h3.125c0,0.552,0.448,1,1,1h3.73L11.346,9z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M13,6c0-1.105-0.895-2-2-2H5V3H3v18h2v-6h5c0,1.105,0.895,2,2,2h6.75L21,6H13zM17.384,15H12v0c0-1.105-0.895-2-2-2H5l0-7h6v0c0,1.105,0.895,2,2,2h5.844L17.384,15z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="follow-channel-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M5.651,12.241C5.884,12.441,6,12.72,6,13c0,0.28-0.116,0.56-0.349,0.76L3,16v-2H0v-2h3v-2L5.651,12.241zM7,11h5V9H7V11zM12,5H7v3h5V5zM4,1v4H1v4h2V7h1v1.924l2,1.661V3h7v10H7v2h6c1.104,0,2-0.896,2-2V1H4z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M7.44,18.657C7.811,19.028,8,19.514,8,20s-0.189,0.972-0.56,1.344L4.784,24l-1.238-1.237L5.319,21H0v-2h5.318l-1.772-1.762L4.783,16L7.44,18.657zM10,18h8v-2h-8V18zM18,6h-8v4h8V6zM10,14h8v-2h-8V14zM6,2v4H2v8h2V8h2v6.007l2,1.971V4h12v15c0,0.552-0.448,1-1,1h-9v2h9c1.657,0,3-1.343,3-3V2H6z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="follow-company-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M14,13v2H7v-3h2v1h2V3H5v6.75L3,8.094V3c0-1.105,0.896-2,2-2h6c1.104,0,2,0.895,2,2v10H14zM10,5H6v2h4V5zM6,10h4V8H6V10zM3,10v2H0v2h3v2l2.651-2.24C5.884,13.56,6,13.28,6,13c0-0.28-0.116-0.559-0.349-0.759L3,10z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M9,14h6v2H9V14zM15,6H9v2h6V6zM19,20V4c0-1.105-0.896-2-2-2H7C5.896,2,5,2.895,5,4v8.795l2,1.985V4h10v16h-4v-2h-2v2h-1v2h11v-2H19zM9,12h6v-2H9V12zM4.783,16l-1.238,1.237L5.318,19H0v2h5.319l-1.772,1.763L4.784,24l2.656-2.656C7.811,20.973,8,20.487,8,20s-0.189-0.973-0.56-1.344L4.783,16z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="follow-person-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M5.651,12.241C5.884,12.441,6,12.72,6,13c0,0.28-0.116,0.56-0.349,0.76L3,16v-2H0v-2h3v-2L5.651,12.241zM14,12.162V14H7v-2h5.25v-0.213c0-0.43-0.4-0.813-0.809-0.949L8,9.733l-2.056,0.642l-1.46-1.234l1.139-0.348C5.244,8.29,5,7.678,5,7V6V5c0-1.657,1.343-3,3-3s3,1.343,3,3v1v1c0,0.678-0.244,1.29-0.624,1.792l1.572,0.524C13.174,9.724,14,10.871,14,12.162zM9,4.5c0-0.551-0.449-1-1-1s-1,0.449-1,1v3c0,0.551,0.449,1,1,1s1-0.449,1-1V4.5z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M16.897,13.632L14.73,12.91C15.508,12.18,16,11.151,16,10V9V7c0-2.209-1.791-4-4-4S8,4.791,8,7v2v1c0,1.151,0.493,2.18,1.271,2.91l-3.055,1.009l1.394,1.394L12,13.858l4.561,1.52c1.531,0.51,2.564,1.943,2.564,3.558V19H10v2h11v-1.676C21,16.742,19.347,14.449,16.897,13.632zM14,10.25c0,1.103-0.897,2-2,2s-2-0.897-2-2v-3.5c0-1.103,0.897-2,2-2s2,0.897,2,2V10.25zM7.44,18.657C7.811,19.028,8,19.514,8,20s-0.189,0.972-0.56,1.344L4.784,24l-1.238-1.237L5.319,21H0v-2h5.318l-1.772-1.762L4.783,16L7.44,18.657z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="follow-school-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,8V4.878c0-0.365-0.199-0.702-0.52-0.877L8,1L1.52,4.001C1.199,4.177,1,4.513,1,4.878V8h2v0.115l2,1.657V8h2v4h6v1H7v2h8v-4c0-0.552-0.448-1-1-1h-1V8H15zM11,10H9V8h2V10zM3,6V5.25l5-2.3l5,2.3V6H3zM5.651,12.241C5.884,12.441,6,12.72,6,13c0,0.28-0.116,0.56-0.349,0.76L3,16v-2H0v-2h3v-2L5.651,12.241z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M21,11V8.177c0-0.726-0.394-1.396-1.029-1.748L12,2L4.029,6.428C3.394,6.781,3,7.45,3,8.177V11h2v1.795l2,2V11h2v6h10v2h-9v2h11v-4c0-1.104-0.896-2-2-2v-4H21zM13,15h-2v-4h2V15zM17,15h-2v-4h2V15zM5,9V7.927l7-3.889l7,3.889V9H5zM7.44,18.657C7.811,19.028,8,19.514,8,20s-0.189,0.972-0.56,1.344L4.784,24l-1.238-1.237L5.319,21H0v-2h5.318l-1.772-1.762L4.783,16L7.44,18.657z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="forward-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M5,6h7.519L9.642,3.145L10.787,2l3.657,3.656C14.814,6.027,15,6.513,15,7c0,0.486-0.185,0.973-0.557,1.344L10.787,12l-1.145-1.145L12.519,8H4.875C3.839,8,3,8.839,3,9.875V13H1v-3C0.998,7.953,2.789,6,5,6z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M22,11c0,0.486-0.189,0.972-0.56,1.343L15.783,18l-1.237-1.237L19.318,12H7.875C5.735,12,4,13.735,4,15.875V20H2v-4c-0.007-3.319,2.681-6,6-6h11.319l-4.772-4.763L15.784,4l5.656,5.656C21.811,10.027,22,10.513,22,11z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="fullscreen-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15,3v3h-2V4h-3V2h4C14.552,2,15,2.448,15,3zM13,12h-3v2h4c0.552,0,1-0.448,1-1v-3h-2V12zM3,10H1v3c0,0.552,0.448,1,1,1h4v-2H3V10zM1,3v3h2V4h3V2H2C1.448,2,1,2.448,1,3z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M22,6v3h-2V6h-5V4h5C21.104,4,22,4.895,22,6zM20,18h-5v2h5c1.104,0,2-0.895,2-2v-3h-2V18zM4,15H2v3c0,1.105,0.896,2,2,2h5v-2H4V15zM2,6v3h2V6h5V4H4C2.896,4,2,4.895,2,6z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="gear-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M6.665,8c0-0.737,0.598-1.335,1.335-1.335S9.335,7.263,9.335,8S8.737,9.335,8,9.335S6.665,8.737,6.665,8zM8.332,2.6h-0.79C7.27,4.073,5.997,5.137,4.494,5.137c-0.353,0-0.701-0.06-1.036-0.179L3.063,5.642C3.755,6.232,4.15,7.089,4.15,8s-0.396,1.768-1.087,2.358l0.395,0.684c0.335-0.119,0.683-0.179,1.036-0.179c1.503,0,2.776,1.064,3.048,2.537h0.79c0.272-1.473,1.545-2.537,3.048-2.537c0.353,0,0.702,0.06,1.036,0.179l0.395-0.684C12.119,9.768,11.724,8.911,11.724,8s0.396-1.768,1.087-2.358l-0.395-0.684c-0.335,0.119-0.683,0.179-1.036,0.179C9.877,5.137,8.604,4.073,8.332,2.6M9.687,1l0.214,1.283c0.125,0.747,0.771,1.254,1.479,1.254c0.174,0,0.352-0.031,0.527-0.096l1.218-0.456l1.75,3.031L13.87,6.842c-0.365,0.3-0.547,0.729-0.547,1.159c0,0.429,0.182,0.858,0.547,1.157l1.004,0.826l-1.75,3.031l-1.218-0.456c-0.175-0.065-0.353-0.096-0.527-0.096c-0.708,0-1.355,0.507-1.479,1.254L9.687,15h-3.5l-0.214-1.283c-0.125-0.747-0.772-1.254-1.479-1.254c-0.174,0-0.352,0.031-0.527,0.096L2.75,13.016L1,9.984l1.004-0.826c0.365-0.3,0.547-0.729,0.547-1.159c0-0.429-0.182-0.858-0.547-1.157L1,6.016l1.75-3.031l1.218,0.456C4.142,3.506,4.32,3.537,4.494,3.537c0.708,0,1.355-0.507,1.479-1.254L6.187,1H9.687L9.687,1z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M12,9c-1.657,0-3,1.343-3,3s1.343,3,3,3s3-1.343,3-3S13.657,9,12,9zM12,13.4c-0.772,0-1.4-0.628-1.4-1.4c0-0.772,0.628-1.4,1.4-1.4s1.4,0.628,1.4,1.4C13.4,12.772,12.772,13.4,12,13.4zM20.279,10.456l1.568-1.291l-2.5-4.33l-1.902,0.713c-0.233,0.087-0.47,0.128-0.702,0.128c-0.943,0-1.806-0.676-1.972-1.672L14.437,2h-5L9.103,4.003C8.937,5,8.075,5.676,7.131,5.676c-0.232,0-0.469-0.041-0.702-0.128L4.527,4.835l-2.5,4.33l1.568,1.291c0.486,0.4,0.729,0.972,0.729,1.544c0,0.572-0.243,1.144-0.729,1.544l-1.568,1.291l2.5,4.33l1.902-0.713c0.233-0.087,0.47-0.128,0.702-0.128c0.943,0,1.806,0.676,1.972,1.672L9.437,22h5l0.334-2.003c0.166-0.996,1.029-1.672,1.972-1.672c0.232,0,0.469,0.041,0.702,0.128l1.902,0.713l2.5-4.33l-1.568-1.291c-0.486-0.4-0.729-0.971-0.729-1.543C19.55,11.429,19.793,10.856,20.279,10.456zM16.743,16.724c-1.767,0-3.26,1.266-3.55,3.009l-0.086,0.516h-2.339l-0.086-0.516c-0.291-1.744-1.784-3.009-3.55-3.009c-0.431,0-0.856,0.077-1.264,0.23l-0.439,0.164L4.25,15.077l0.362-0.298C5.446,14.093,5.924,13.08,5.924,12S5.446,9.907,4.612,9.221L4.25,8.923l1.179-2.041l0.439,0.164c0.407,0.153,0.832,0.23,1.264,0.23c1.767,0,3.26-1.266,3.55-3.009l0.086-0.516h2.339l0.086,0.516c0.291,1.744,1.784,3.009,3.55,3.009c0.431,0,0.856-0.077,1.264-0.23l0.542-0.203l1.161,2.01l-0.447,0.368C18.429,9.907,17.95,10.92,17.95,12s0.478,2.093,1.312,2.779l0.447,0.368l-1.161,2.01l-0.542-0.203C17.6,16.802,17.174,16.724,16.743,16.724z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="globe-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M8,1C4.134,1,1,4.134,1,8s3.134,7,7,7c3.866,0,7-3.134,7-7S11.866,1,8,1zM9.5,11L8,10.183V10h2L9.5,11zM6.5,6.202L4.515,4.217C5.435,3.368,6.653,2.838,8,2.838v1.864L6.5,6.202zM2.838,8c0-0.908,0.256-1.75,0.67-2.493L6,8v2.382c0,0.379,0.214,0.725,0.553,0.894L8,12v1.162C5.153,13.162,2.838,10.847,2.838,8zM10.521,12.562l1.192-2.432c0.172-0.379,0.091-0.826-0.203-1.121l-0.717-0.717C10.605,8.105,10.351,8,10.086,8H8V7l1.707-1.707C9.895,5.105,10,4.851,10,4.586V3.241C11.856,4.025,13.163,5.862,13.163,8C13.163,10.042,11.999,11.653,10.521,12.562z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M12,2C6.477,2,2,6.477,2,12s4.477,10,10,10c5.523,0,10-4.477,10-10S17.523,2,12,2zM12,3.75c0.34,0,0.672,0.032,1,0.074v2.67L11.469,8H9v1.676L5.718,6.666C7.232,4.885,9.485,3.75,12,3.75zM12,20.25c-4.549,0-8.25-3.701-8.25-8.25c0-1.4,0.353-2.718,0.97-3.874L9,12.077v3.187c0,0.758,0.428,1.45,1.106,1.789L12,18V20.25zM14,20v-3l-3-1.444V14h4l1.339,1.349L14,20zM16.478,18.919l1.315-2.63c0.385-0.77,0.234-1.7-0.375-2.309l-1.395-1.395C15.648,12.211,15.14,12,14.609,12H11v-2h0.104c0.521,0,1.021-0.203,1.395-0.567l1.896-1.844C14.782,7.212,15,6.695,15,6.156V4.323C18.068,5.526,20.25,8.51,20.25,12C20.25,14.898,18.745,17.447,16.478,18.919z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="grid-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M2,10h4v4H2V10zM2,6h4V2H2V6zM10,14h4v-4h-4V14zM10,2v4h4V2H10z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
#       <path d="M3,3h4v4H3V3zM10,21h4v-4h-4V21zM3,21h4v-4H3V21zM3,14h4v-4H3V14zM10,7h4V3h-4V7zM17,3v4h4V3H17zM17,14h4v-4h-4V14zM10,14h4v-4h-4V14zM17,21h4v-4h-4V21z">
#       </path>
#      </svg>
#     </svg>
#     <svg height="24px" id="group-icon" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0">
#      <svg class="small-icon" style="fill-opacity: 1;">
#       <path d="M15.999,12.408L16,11.817c0-0.861-0.551-1.625-1.368-1.897l-1.003-0.441C13.857,9.215,14,8.876,14,8.5v-1C14,6.672,13.328,6,12.5,6S11,6.672,11,7.5v1c0,0.342,0.119,0.654,0.312,0.906L9.306,8.504C9.728,8.137,10,7.603,10,7V6c0-1.105-0.896-2-2-2S6,4.895,6,6v1c0,0.603,0.272,1.137,0.694,1.504L4.687,9.408C4.88,9.155,5,8.843,5,8.5v-1C5,6.672,4.328,6,3.5,6S2,6.672,2,7.5v1c0,0.376,0.143,0.715,0.371,0.978L1.368,9.919C0.551,10.191,0,10.956,0,11.817l0.001,0.594C2.451,14.196,5.203,15,8,15s5.549-0.804,7.998-2.589l0,0v0L16,12.409L15.999,12.408zM14.25,11.478c-0.728,0.455-1.481,0.812-2.25,1.088v-1.76l0.5-0.193l1.75,0.704V11.478zM7.625,5.75c0-0.207,0.168-0.375,0.375-0.375S8.375,5.543,8.375,5.75v1.5c0,0.207-0.168,0.375-0.375,0.375S7.625,7.457,7.625,7.25V5.75zM3.5,10.612L4,10.805v1.76c-0.769-0.276-1.522-0.633-2.25-1.088v-0.161L3.5,10.612zM6,13.09v-2.524l2-0.897l2,0.897v2.524c-0.662,0.111-1.33,0.17-2,0.17S6.662,13.201,6,13.09zM4.273,5H2.349C3.173,2.671,5.389,1,8,1s4.827,1.671,5.651,4h-1.925C11.009,3.668,9.617,2.75,8,2.75S4.991,3.668,4.273,5z">
#       </path>
#      </svg>
#      <svg class="large-icon" style="fill: currentColor;">
# ...
#            </a>
#           </li>
#          </ul>
#          <input name="i18nLang" type="hidden" value=""/>
#          <input name="currenturl" type="hidden" value="https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsearch%3Fkeywords%3DData%2BScientist%26locationId%3DSTATES%2Eus%2Eny%26start%3D0%26count%3D25%26trk%3Djobs_jserp_pagination_next%26urlhash%3DRUcO"/>
#         </form>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/redir/redirect?url=http%3A%2F%2Fwww%2Eslideshare%2Enet&amp;urlhash=nLLC" target="_blank">
#          SlideShare
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/premium/lynda/landing?trk=hb_ft_lynda" target="_blank">
#          Online Learning
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <nav aria-label="Footer Directory Menu" role="navigation">
#       <ul class="nav-footer li-links" role="menubar">
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/in/updates?trk=hb_ft_liup">
#          LinkedIn Updates
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/today/post/whoToFollow?trk=hb_ft_influencers">
#          LinkedIn Influencers
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/job/?trk=hb_ft_jobs">
#          Search Jobs
#         </a>
#        </li>
#       </ul>
#       <ul class="nav-footer directories" role="menubar">
#        <li>
#         Directories
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/people-a/?trk=hb_ft_peopledir">
#          Members
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/jobs2/directory/?trk=hb_ft_jobs2_dir">
#          Jobs
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/pulse/">
#          Pulse
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/topics/">
#          Topics
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/companies/">
#          Companies
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/groups/">
#          Groups
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/universities/">
#          Universities
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/directory/title/">
#          Titles
#         </a>
#        </li>
#        <li class="last" role="menuitem">
#         <a href="http://www.linkedin.com/profinder?trk=hb_ft_profinder">
#          ProFinder
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <p class="copyright guest">
#       <span>
#        LinkedIn Corporation
#       </span>
#       <em>
#        © 2016
#       </em>
#      </p>
#      <ul aria-label="Footer Legal Menu" class="nav-legal" role="navigation">
#       <li role="menuitem">
#        <a href="http://www.linkedin.com/legal/user-agreement?trk=hb_ft_userag">
#         User Agreement
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="http://www.linkedin.com/legal/privacy-policy?trk=hb_ft_priv">
#         Privacy Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="https://linkedin.com/help/linkedin/answer/34593?lang=en">
#         Community Guidelines
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="http://www.linkedin.com/legal/cookie-policy?trk=hb_ft_cookie">
#         Cookie Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="http://www.linkedin.com/legal/copyright-policy?trk=hb_ft_copy">
#         Copyright Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="/psettings/guest-email-unsubscribe?trk=hb_ft_gunsub" rel="nofollow">
#         Unsubscribe
#        </a>
#       </li>
#      </ul>
#     </div>
#    </footer>
#    <script data-page-js-type="config">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#
#                                 a = r['WebTracking'] = r['WebTracking'] || {};
#                                 a['URLs'] = {'saveWebActionTrackURL':'\/lite\/secure-web-action-track?csrfToken=ajax%3A3719158201539583969'};
#
#
#
#                     }('__li__config_registry__'));
#    </script>
#    <script data-page-js-type="lix">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#                             r['global_bsp_notice_type'] = 'warning';
#
#
#
#                             r['global_bsp_notice_autoHide'] = 'false';
#
#
#
#                             r['global_bsp_view_threshold'] = 'c5';
#
#
#                     }('__li__lix_registry__'));
#    </script>
#    <script data-page-js-type="i18n">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#                             r['global_browser_unsupported_notice'] = 'Looks like you\'re using a browser that\'s not supported. <a target=\"_blank\" href=\"https:\/\/linkedin.com\/help\/linkedin\/answer\/4135?lang=en\">Learn more about browsers you can use.<\/a>';
#
#
#                     }('__li__i18n_registry__'));
#    </script>
#    <script data-page-js-type="config">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#
#                                 a = r['global:browserSupportPolicy'] = r['global:browserSupportPolicy'] || {};
#                                 a['supportedBrowserMinVersions'] = {      ie:             'v10',      firefox:        'v38',      opera:          'control',      safari:         'v6.1',      chrome:         'v42',      mobileSafari:   'v7',      android:        'v2.3',      androidChrome:  'v0'    };
#
#
#
#                     }('__li__config_registry__'));
#    </script>
#    <script type="text/javascript">
#     (function(d, f) {
#  var modQuot = parseInt(f.substring(1), 10);
#  var now = (+new Date());
#  if (typeof modQuot === 'number' && (now % modQuot !== 0)) {
#  return;
#  }
#  function go() {
#  var a = d.createElement('iframe');
#  a.style.display = 'none';
#  a.setAttribute('sandbox', 'allow-scripts allow-same-origin');
#  a.src = '//platform.linkedin.com/js/thirdPartyJSDelegatorFrame.html?type=dyndns';
#  if (d.body) {
#  d.body.appendChild(a);
#  }
#  }
#
#  if (window.addEventListener) {
#  window.addEventListener('load', go, false);
#  } else if (window.addEvent) {
#  window.addEvent('onload', go);
#  }
#  }(document, 'n100'));
#    </script>
#    <script src="https://static.licdn.com/scds/concat/common/js?h=3kp2aedn5pmamdr4dk4n8atur-3ti5bgrnb6idjtk0w4chaigxe-5hqr1i1uoezoj0z1s5gcxojf2-71o37tcjwl0ishto9izvyml3i-3bbdjshpw5ov0rwa8xe08tp97-cayct4cirf7n0f9z1xsg84g0q-dktkawxk7k8pixuh5g8z5ku32-213zbp2wzp99lviwl8g2cvq6i-1lknwtftishpdmobzm413yc7u-bcxa0v9ke411pjpmz4s239f9b-10wg3j2jlwnawjalr4lur4ho3-82rcsw42m1wbgsti4m3j0kvg6-f3la2n4kbk7vr56j54qax1oif-1eq1il9757v2zkuru6hu14q2e-8sox1gztdjnz2un89fi8fyw35-8hdbl769kuhp0h4bsexhsbks0-d8q8zy9bxe530nqv2fct70nwo-c6ct0moql4p4ngtzltmf8l3ly-8h514j3fiwnzuwkt66sbxsu8f-di2z9sra5co9la7ogqyesywin" type="text/javascript">
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("globalVariableModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("metaTagModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("breadcrumbsModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("relatedJobSearchModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("UILixModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("jobSearchAlertModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("searchValuesModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("decoratedJobPostingsModule");},false);})()
#    </script>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("facetResultsModule");},false);})()
#    </script>
#    <script type="text/javascript">
#     (function () {
#     var config;
#     if (!window.__li__config_registry__) {
#       window.__li__config_registry__ = {};
#     }
#
#     config = window.__li__config_registry__;
#
#     if (!config.jobSearch) {
#       config.jobs = {};
#     }
#
#     config.jobs.embeddedContentIds = {
#       facetResultsModule: 'facetResultsModule',
#       metaTagModule: 'metaTagModule',
#       globalVariableModule: 'globalVariableModule',
#       guestChrome: 'guestChromeDisplayModule',
#       searchValuesModule: 'searchValuesModule',
#       breadcrumbsModule: 'breadcrumbsModule',
#       relatedJobSearchModule: 'relatedJobSearchModule',
#       decoratedJobPostingsModule: 'decoratedJobPostingsModule',
#       jobSearchAlertModule: 'jobSearchAlertModule',
#       UILixModule: 'UILixModule',
#       pivotQueryBannerModule: 'pivotQueryBannerModule',
#       distanceModule: 'distanceModule',
#       timePostedModule: 'timePostedModule',
#       searchHistoryDisplayModule: 'searchHistoryDisplayModule',
#       memberProfileDisplayModule: 'memberProfileDisplayModule',
#       helpCenterModule: 'helpCenterModule',
#       noResultModule: 'noResultModule',
#       spellingSuggestionsModule: 'spellingSuggestionsModule'
#     };
#    }());
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.367/f/%2Fjobs-frontend%2Fconcat%2Fapp-dist_en_US.js" type="text/javascript">
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.367/f/%2Fjobs-frontend%2Fconcat%2Fmarionette-job-search-templates_en_US.js" type="text/javascript">
#    </script>
#    <script>
#     (function () {
#    document.addEventListener('flushReady', function () {
#       window.__LI_JOBS_DS__.flushCompleted();
#      }, false);
#   })();
#    </script>
#    <script type="text/javascript">
#     if (!window.LI) { window.LI = {}; }
#  LI.RUM = LI.RUM || {};
#
#  (function(RUM, win) {
#
#  var doc = win.document;
#
#  RUM.flags = RUM.flags || {};
#  RUM.flags['host-flag'] = "control";
#  RUM.flags['pop_beacons_frequency'] = "n10-ap0-la0-va0-tx0-sg0-db0-hk0-sp0-ln0-ch0-sy0-mu0-mi0";
#  RUM.flags['rs_timings_individual'] = "n1000";
#  RUM.flags['rs_timings_individual_detail'] = "enabled";
#
#  RUM.urls = RUM.urls || {};
#  RUM.urls['rum-track'] = "\/lite\/rum-track?csrfToken=ajax%3A3719158201539583969";
#  RUM.urls['boomerang-bw-img'] = "https:\/\/static.licdn.com\/scds\/common\/u\/lib\/boomerang\/0.9.edge.4ab208445a\/img\/";
#
#  RUM.base_urls = RUM.base_urls || {};
#  RUM.base_urls['permanent_content'] = "https:\/\/static.licdn.com\/scds\/common\/u\/";
#  RUM.base_urls['versioned_content'] = "https:\/\/static.licdn.com\/scds\/concat\/common\/";
#  RUM.base_urls['media_proxy'] = "https:\/\/media.licdn.com\/media-proxy\/";
#
#  RUM.serverStartTime = 1.476545849096E12;
#
#  RUM.enabled = true;
#
#  function getRumScript() {
#  var node = doc.body || doc.head || doc.getElementsByTagName('head')[0],
#  script = doc.createElement('script');
#  script.src =
#  ["https://static.licdn.com/scds/concat/common/js?h=ed29nkjpsa16bhrjq4na16owq-1mucgfycc664m7vmhpjgqse65-1l5rurej3h44qodo5rn0cdvyn-8om6v2ckrxsbnwf40t9ta8a7e-34tiets5jpj294jd59h8c4s0n-28w7d5j2k2jtil9ncckolke4m-9jzlwicvu376y9q4vjq77y5ks-1m0whdrwis44c1hoa9mrwhlt4-1uvutm1mpyov7rqhtcf8fksby-aac54ic1fmca5xz1yvc5t9nfe-1hn40w0bomeivihj9lopp4hp2-c0121povror81d0xao0yez4gy"]
#  [0];
#  node.appendChild(script);
#  }
#
#  if (win.addEventListener) {
#  win.addEventListener('load', getRumScript);
#  }
#  else {
#  win.attachEvent('onload', getRumScript);
#  }
#
#  }(LI.RUM, window));
#    </script>
#    <meta content="//platform.linkedin.com/js/px.js" name="detectAdBlock"/>
#    <script async="" defer="" src="https://static.licdn.com/scds/concat/common/js?h=69w33ou4umkyupw2uqgn7za7w">
#    </script>
#    <script class="comscore-tracking">
#     (function(_e, _r) {
#  var isNielsenDisabled = true;
#  var providers = {
#  'COMSCORE': {
#  'treatment': 'control'
#  }
#  };
#  if (!isNielsenDisabled) {
#  providers['NIELSEN'] = {
#  'treatment': 'control'
#  };
#  }
#
#  var fireComscore = function() {
#  var comScore = window.COMSCORE;
#  if (comScore) {
#  comScore.beacon({ c1: 2, c2: 6402952, c3: '', c4: '', c5: '', c6: '', c15: '' });
#  }
#  };
#
#  var uc = window.encodeURIComponent, timeStamp = (new Date()).getTime();
#  var fireExternalTracking = function(et) {
#  if (typeof et.trackPageChromeInit === 'function') {
#  et.trackPageChromeInit(providers);
#  } else {
#  // Default treatment if not read from LIX.
#  et.setTreatment('enabled_1.0');
#  et.trackWithComScoreForChromeInit();
#  if (!isNielsenDisabled) {
#  var img = new Image(1, 1);
#  img.onerror = img.onload = function () {
#  img.onerror = img.onload = null;
#  };
#  img.src = [
#  "//secure-gl.imrworldwide.com/cgi-bin/m?ci=au-linkedin&cc=1&si=",
#  uc(window.location.href),
#  "&rp=", uc(document.referrer), "&ts=compact&rnd=", timeStamp
#  ].join('');
#  }
#  }
#  };
#  var track = function() {
#  var et;
#  if (_e) {
#  fireExternalTracking(_e);
#  } else if (_r && typeof _r.ensure === 'function') {
#  try {
#  _r.ensure(['externalTracking'], function (require) {
#  try {
#  et = require('externalTracking');
#  fireExternalTracking(et);
#  } catch (e) {
#  fireComscore();
#  }
#  });
#  } catch (e) {
#  fireComscore();
#  }
#  } else if (_r && _r._is_li) {
#  try {
#  et = require('externalTracking');
#  fireExternalTracking(et);
#  } catch (e) {
#  fireComscore();
#  }
#  } else {
#  fireComscore();
#  }
#  };
#  window.addEventListener('load', track);
#  }(window.externalTracking, window.require));
#    </script>
#    <noscript>
#     &lt;img src="https://sb.scorecardresearch.com/b?c1=2&amp;amp;c2=6402952&amp;amp;c3=&amp;amp;c4=&amp;amp;c5=&amp;amp;c6=&amp;amp;c15=&amp;amp;cv=1.3&amp;amp;cj=1" style="display:none" width="0" height="0" alt="" /&gt;
#    </noscript>
#    <script type="text/javascript">
#     (function(d) {
#  function go() {
#  var a = d.createElement('iframe');
#  a.style.display = 'none';
#  a.setAttribute('sandbox', 'allow-scripts allow-same-origin');
#  a.src = '//radar.cedexis.com/1/11326/radar/radar.html';
#  if (d.body) {
#  d.body.appendChild(a);
#  }
#  }
#
#  if (window.addEventListener) {
#  window.addEventListener('load', go, false);
#  } else if (window.addEvent) {
#  window.addEvent('onload', go);
#  }
#  }(document));
#    </script>
#   </div>
#   <script src="https://static.licdn.com/scds/concat/common/js?h=ed29nkjpsa16bhrjq4na16owq-1mucgfycc664m7vmhpjgqse65-1l5rurej3h44qodo5rn0cdvyn-8om6v2ckrxsbnwf40t9ta8a7e-34tiets5jpj294jd59h8c4s0n-28w7d5j2k2jtil9ncckolke4m-9jzlwicvu376y9q4vjq77y5ks-1m0whdrwis44c1hoa9mrwhlt4-1uvutm1mpyov7rqhtcf8fksby-aac54ic1fmca5xz1yvc5t9nfe-1hn40w0bomeivihj9lopp4hp2-c0121povror81d0xao0yez4gy">
#   </script>
#   <script src="//platform.linkedin.com/js/px.js?ch=1">
#   </script>
#   <iframe sandbox="allow-scripts allow-same-origin" src="//radar.cedexis.com/1/11326/radar/radar.html" style="display: none;">
#   </iframe>
#   <script src="//platform.linkedin.com/js/px.js?ch=2">
#   </script>
#  </body>
# </html>

# %%
for i in soup2.findAll('div', class_='job-details'):
    print i.find('span', class_='job-title-text').text
    print i.find('span', class_='company-name-text').text
    print i.find('span', class_='job-location').text
    print i.find('div', class_='job-description').text
#     print i.prettify()
    print""
# Out:
# Data Scientist
# 2U
# Greater New York City Area
# This is a highly quantitative role that requires analytical aptitude, strong programming skills, intellectual curiosity and the ability ...
#
# Data Scientist
# Scholastic
# New York, New York
# Scholastic is a seeking a highly skilled, creative, and driven Data Scientist to design and build approaches which will help Scholastic ...
#
# Data Scientist
# Wylei
# Greater New York City Area
# Compensation is benchmarked to market rates and is commensurate with candidate experience level. Professional experience as a data scientist.
#
# Data Scientist
# Smith Hanley Associates
# Greater New York City Area
# This position exists within the Methodology and Protocols team, a core function in Research Science that is responsible for developing ...
#
# Data Scientist
# National Grid
# Brooklyn, New York
# The Data Scientist is responsible for working to provide data driven solutions and conclusions from several different sources of ...
#
# Data Scientist
# Komodo Health
# Greater New York City Area
# 2+ years experience with Python, Scala, or Java and distributed frameworks (Hadoop, Spark, etc. SQL and Relational Databases.
#
# Data Scientist
# Credit Suisse
# New York
# This role demands niche skills in PNL, Machine Learning and Big Data Analytics. Join us and let's shape the future of Credit Suisse together.
#
# Data Scientist
# Macy's
# New York, NY
# Experience working with large data sets and distributed computing tools such as Hadoop, Map/Reduce, Hive, etc.
#
# Data Scientist
# Sidewalk Labs
# New York, New York
# We’re looking for someone to understand, with the help of our policy team, significant urban problems that can be ameliorated with data,...
#
# Data Scientist
# Wink, Inc.
# Greater New York City Area
# Bayesian statistics/probability- Experience with building simple probabilistic models, simulations, and other computational techniques to...
#
# Data Scientist
# Predictive Science
# New York City, NY, US
# Predictive Science is looking for a Data Scientist who can work with Fortune 1000 companies and other companies around the world to help ... ziprecruiter.com
#
# Data Scientist
# Aetna
# New York
# We are currently looking for an exceptional Data Scientist to play a pivotal role in the creation and deployment of population health ...
#
# Data Scientist
# The Raymond Corporation- A Division of Toyota Material Handling USA
# Greene, New York
# Relevant experience using statistical / quantitative modeling and/or machine learning tools (SAS, SQL, R, Python, SAP Predictive ...
#
# Data Scientist
# Squarespace
# Greater New York City Area
# We are currently seeking multiple Data Scientists who demonstrate sharp intellectual curiosity, a collaborative work ethic, and expertise...
#
# Data Scientist
# Biz2Credit
# New York City, NY, US
# We’re looking for an exceptional candidate that is excited about the opportunity to build a next generation financial services business. ziprecruiter.com
#
# Data Scientist
# Via - On-Demand Transit
# New York City, NY, US
# Have experience with predictive modeling and statistical analysis techniques in a business environment. Via is an equal opportunity employer. via.workable.com
#
# Data Scientist
# SecurityScorecard
# New York City, NY, US
# We’re working on some interesting problems, and we’re searching for a Data Scientist who’ll help us develop predictive models and ... jsco.re
#
# Data Scientist
# WebMD
# New York City, NY, US
# Work experience and a sophisticated knowledge of techniques such as data merging, collapsing, manipulating to construct analytical files. careers-webmd.icims.com
#
# Data Scientist
# InfiCare Software Technologies
# New York City, NY, US
# Leadership Capability, Self-motivated, Exceptional analytical and problem solving skills and ability to present convincingly to technical... smartrecruiters.com
#
# Data Scientist
# Vroom
# New York City, NY, US
# We're looking for a data scientist who can bring fresh ideas and a data-driven attitude to help us disrupt the stagnant used car industry. workable.com
#
# Data Scientist
# IBM
# New York City, NY, US
# As such, the ideal candidate will not just address business problems through the application of data technology but also be able to ... krb-sjobs.brassring.com
#
# Data Scientist
# TodayTix
# New York City, NY, US
# We're seeking highly motivated team members to join us in disrupting an old supply chain model, to broaden access to theater, and expand ... todaytix.applytojob.com
#
# Data Scientist
# Numeric Jobs
# New York, New York
# As a Customer Facing Data Scientists you will be expected to work with the Field Sales team members and lead Junior Sales Engineers in ...
#
# Data Scientist
# The Weather Company, an IBM Business
# Greater New York City Area
# Minimum 7 - 12 years experience in data sciences and technology management, media experience preferred. Familiarity with meteorological data.
#
# Data Scientist
# Booz Allen Hamilton
# New York City, NY, US
# Experience with machine learning, data mining, statistics, or graph algorithms in an academic or internship environment. jobs.net
